# %% [markdown]
# 本文主要以kaggle一次二分类竞赛数据为例，深入研究改进forest
#
# LayerDTree是LayerForest的精简版，是对Forest进一步探索的基础
#
# - 数据地址：https://www.kaggle.com/c/porto-seguro-safe-driver-prediction
# - 数据特点：
#   - 非常不均衡、缺失值严重、二分类
# - 包含内容：
#   1. 数据获取
#   2. 模型应用
#   3. 结果分析

# %% [markdown]
# # Stage-1：获取数据

# %%
import os
import numpy as np
import pandas as pd
import time
import os.path as osp

# %%
class FeatureParser(object):
    def __init__(self, desc):
        desc = desc.strip()
        if desc == "C":
            self.f_type = "number"
        else:
            self.f_type = "categorical"
            f_names = [d.strip() for d in desc.split(",")]
            # missing value
            f_names.insert(0, "?")
            self.name2id = dict(zip(f_names, range(len(f_names))))

    def get_float(self, f_data):
        f_data = f_data.strip()
        if self.f_type == "number":
            return float(f_data)
        return float(self.name2id[f_data])

    def get_data(self, f_data):
        f_data = f_data.strip()
        if self.f_type == "number":
            return float(f_data)
        data = np.zeros(len(self.name2id), dtype=np.float32)
        data[self.name2id[f_data]] = 1
        return data

    def get_fdim(self):
        """
        get feature dimension
        """
        if self.f_type == "number":
            return 1
        return len(self.name2id)

# %%
train_data_path = osp.join(".\\datasetes", "adult", "adult.data")
test_data_path = osp.join(".\\datasetes", "adult", "adult.test")
feature_desc_path = osp.join(".\\datasetes", "adult", "features")
train_data_path, test_data_path, feature_desc_path
# Out:
# ('.\\datasetes\\adult\\adult.data',
#  '.\\datasetes\\adult\\adult.test',
#  '.\\datasetes\\adult\\features')

# %%
f_parsers = []
with open(feature_desc_path) as f:
    for row in f.readlines():
        f_parsers.append(FeatureParser(row))
# f_parsers

# %%
with open(train_data_path) as f:
    rows = [row.strip().split(",") for row in f.readlines() if len(row.strip()) > 0 and not row.startswith("|")]
n_datas = len(rows)

cate_as_onehot = 0
if cate_as_onehot:
    X_dim = np.sum([f_parser.get_fdim() for f_parser in f_parsers])
    X = np.zeros((n_datas, X_dim), dtype=np.float32)
else:
    X = np.zeros((n_datas, 14), dtype=np.float32)
y = np.zeros(n_datas, dtype=np.int32)
for i, row in enumerate(rows):
    assert len(row) == 15, "len(row) wrong, i={}".format(i)
    foffset = 0
    for j in range(14):
        if cate_as_onehot:
            fdim = f_parsers[j].get_fdim()
            X[i, foffset:foffset+fdim] = f_parsers[j].get_data(row[j].strip())
            foffset += fdim
        else:
            X[i, j] = f_parsers[j].get_float(row[j].strip())
    y[i] = 0 if row[-1].strip().startswith("<=50K") else 1
print(X.shape, y.shape)
X_train = X
y_train = y
# Out:
# (32561, 14) (32561,)

# %%
with open(test_data_path) as f:
    rows = [row.strip().split(",") for row in f.readlines() if len(row.strip()) > 0 and not row.startswith("|")]
n_datas = len(rows)

cate_as_onehot = 0
if cate_as_onehot:
    X_dim = np.sum([f_parser.get_fdim() for f_parser in f_parsers])
    X = np.zeros((n_datas, X_dim), dtype=np.float32)
else:
    X = np.zeros((n_datas, 14), dtype=np.float32)
y = np.zeros(n_datas, dtype=np.int32)
for i, row in enumerate(rows):
    assert len(row) == 15, "len(row) wrong, i={}".format(i)
    foffset = 0
    for j in range(14):
        if cate_as_onehot:
            fdim = f_parsers[j].get_fdim()
            X[i, foffset:foffset+fdim] = f_parsers[j].get_data(row[j].strip())
            foffset += fdim
        else:
            X[i, j] = f_parsers[j].get_float(row[j].strip())
    y[i] = 0 if row[-1].strip().startswith("<=50K") else 1
print(X.shape, y.shape)
X_sub = X
y_sub = y
# Out:
# (16281, 14) (16281,)

# %% [markdown]
# # Stage-2：模型应用

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedShuffleSplit
import ForestUtils
import time
import random
from sklearn import metrics

# %%
import EnhancedDTree
import importlib

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
importlib.reload(EnhancedDTree)
# Out:
# <module 'EnhancedDTree' from 'C:\\github_workspace\\LayerForest\\EnhancedDTree.py'>

# %% [markdown]
# # 决策树算法

# %%
clf = DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
clf = clf.fit(X_train, y_train)

# %%
p_train = clf.predict_proba(X_sub)
p_train = [item[1] for item in p_train]
p_train = np.array(p_train)
print("data auc", metrics.roc_auc_score(y_sub, p_train))
# Out:
# data auc 0.74431797296

# %%
p_train = clf.predict(X_sub)
print("data auc", metrics.accuracy_score(y_sub, p_train))
# Out:
# data auc 0.813402125177

# %% [markdown]
# # 随机森林算法

# %%
rf = RandomForestClassifier(n_estimators=2000, max_depth=16, n_jobs=4, random_state=1024, verbose=True)
rf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=16, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=2000, n_jobs=4,
#             oob_score=False, random_state=1024, verbose=True,
#             warm_start=False)

# %%
rf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=4)]: Done 2000 out of 2000 | elapsed:   15.7s finished
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=16, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=2000, n_jobs=4,
#             oob_score=False, random_state=1024, verbose=True,
#             warm_start=False)

# %%
p_train = rf.predict_proba(X_sub)
p_train = [item[1] for item in p_train]
p_train = np.array(p_train)
print("data auc", metrics.roc_auc_score(y_sub, p_train))
# Out:
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 2000 out of 2000 | elapsed:    1.9s finished
# data auc 0.917365234215

# %%
p_train = rf.predict(X_sub)
print("data acc", metrics.accuracy_score(y_sub, p_train))
# Out:
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done 2000 out of 2000 | elapsed:    1.9s finished
# data acc 0.865303114059

# %% [markdown]
# # XGB算法

# %%
import xgboost as xgb

# %%
params = {
    'objective': 'binary:logistic',
    'silent': True,
    
    'max_depth': 4,
    'eta': 0.020,
    'gamma': 0.65,
    
    'colsample_bytree': 0.8,
    'subsample': 0.6,
    
    'num_boost_round' : 700,
#     'min_child_weight': 10.0,
#     'max_delta_step': 1.8,
}

# %%
# Define the gini metric - from https://www.kaggle.com/c/ClaimPredictionChallenge/discussion/703#5897
def ginic(actual, pred):
    actual = np.asarray(actual) #In case, someone passes Series or list
    n = len(actual)
    a_s = actual[np.argsort(pred)]
    a_c = a_s.cumsum()
    giniSum = a_c.sum() / a_s.sum() - (n + 1) / 2.0
    return giniSum / n

def gini_normalized(a, p):
#     if p.ndim == 2:#Required for sklearn wrapper
#         p = p[:,1] #If proba array contains proba for both 0 and 1 classes, just pick class 1
    return ginic(a, p) / ginic(a, a)

# Create an XGBoost-compatible metric from Gini
def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return 'gini', gini_score

# %%
d_train = xgb.DMatrix(X_train, y_train)
d_valid = xgb.DMatrix(X_sub, y_sub)
watchlist = [(d_train, 'train'), (d_valid, 'valid')]

mdl = xgb.train(params, d_train, 
                    num_boost_round=1600, evals=watchlist, early_stopping_rounds=100, 
                    feval=gini_xgb, maximize=True, verbose_eval=100)
# Out:
# [0]	train-gini:0.691894	valid-gini:0.700265
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [100]	train-gini:0.819327	valid-gini:0.816554
# [200]	train-gini:0.836354	valid-gini:0.830442
# [300]	train-gini:0.847753	valid-gini:0.839445
# [400]	train-gini:0.856274	valid-gini:0.845215
# [500]	train-gini:0.861858	valid-gini:0.848523
# [600]	train-gini:0.866693	valid-gini:0.850783
# [700]	train-gini:0.870262	valid-gini:0.851864
# [800]	train-gini:0.87336	valid-gini:0.853076
# [900]	train-gini:0.876152	valid-gini:0.853475
# [1000]	train-gini:0.878787	valid-gini:0.854279
# [1100]	train-gini:0.881256	valid-gini:0.854657
# [1200]	train-gini:0.883566	valid-gini:0.854888
# [1300]	train-gini:0.885647	valid-gini:0.855086
# [1400]	train-gini:0.887623	valid-gini:0.855218
# [1500]	train-gini:0.88951	valid-gini:0.85506
# Stopping. Best iteration:
# [1412]	train-gini:0.88786	valid-gini:0.855257

# %%
d_test = xgb.DMatrix(X_sub)
p_train = mdl.predict(d_test)
print("data auc", metrics.roc_auc_score(y_sub, p_train))
# Out:
# data auc 0.927533951378

# %%
test_y_acc_index = np.where(p_train > 0.5)[0]
test_y_acc = np.array([0] * len(p_train))
test_y_acc[test_y_acc_index] = 1
metrics.accuracy_score(y_sub, test_y_acc)
# Out:
# 0.87414777962041645

# %% [markdown]
# # layerDTree算法

# %%
importlib.reload(EnhancedDTree)
# Out:
# <module 'EnhancedDTree' from 'C:\\github_workspace\\LayerForest\\EnhancedDTree.py'>

# %%
def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=np.float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)

def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

def gini_metrix(a, p):
    return "nor gini:", gini_normalized(a,p)

# %%
X = X_train.copy()
y = y_train.copy()

X_test = X_sub.copy()
test_y = np.array(([0.0] * len(X_test)))
all_data_mask = np.array([False] * len(X_test))
real_y = y_sub.copy()

# 均衡数据进行layer
X_train_np = X
y_train_np = y
maxlayer = 100
layer = 0

enhancedDTree = EnhancedDTree.EnhancedDTree()
counter = 0
while 1:
    layer += 1
    print()
    print("layer:", layer)
    X = X_train_np
    y = y_train_np
    
    # 均衡数据
    positive_mask = np.where(y == 1)[0]
    negative_index = np.where(y == 0)[0]
    random.shuffle(negative_index)
    negative_mask = negative_index[:len(positive_mask)]
    train_mask = np.hstack((positive_mask, negative_mask))
    train_data_x = X[train_mask]
    train_data_y = y[train_mask]
    guest_mask = negative_index[len(positive_mask):]
    guest_data_x = X[guest_mask]
    guest_data_y = y[guest_mask]
    
    print("train==1", train_data_y[train_data_y == 1].shape)
    print("train==0", train_data_y[train_data_y == 0].shape)
    clf, data_mask, all_false_data_index, p_test  = \
        enhancedDTree.TrainModelLayer(train_data_x, train_data_y, X_test, all_data_mask, test_y, real_y, verbose=True, feval=gini_metrix)
        
    X_train_np = enhancedDTree.X_train_np
    y_train_np = enhancedDTree.y_train_np
    
    # 均衡数据
    X_train_np = np.vstack((X_train_np, guest_data_x))
    y_train_np = np.hstack((y_train_np, guest_data_y))
    print("train==1", y_train_np[y_train_np == 1].shape)
    print("train==0", y_train_np[y_train_np == 0].shape)
    
#     time.sleep(1)
    if X_train_np.shape[0] < 1000 or layer > maxlayer or y_train_np[y_train_np==1].shape[0] <= 10 \
        or len(p_test[~data_mask]) == 0:
        all_data_mask = all_false_data_index[~data_mask]
        test_y[all_data_mask] = p_test[~data_mask]
        print(len(p_test[~data_mask]))
        break
        
    all_data_mask[~all_data_mask] = data_mask
# Out:
# layer: 1
# train==1 (7841,)
# train==0 (7841,)
# X_train.shape, y_train.shape:(13329, 14)(13329,)
# X_valid.shape, y_valid.shape:(2353, 14)(2353,)
# all data ('nor gini:', 0.82967020482218001)
# train data ('nor gini:', 0.81905350287151635)
# valid data ('nor gini:', 0.80213300273380383)
# mean of all impurity:0.0
# pass node id shape:(7,)
# pass data shape:(2932, 14) (1589,)
# not pass data shape:(12750, 14) (46525,)
# all data shape:15682
# mean of all impurity:0.273708010192
# pass node id shape:(73,)
# pass test data shape: 9199
# not pass test data shape: 7082
# pass test data ('nor gini:', 0.93871838660069928)
# train==1 (6252,)
# train==0 (23377,)
#
# layer: 2
# train==1 (6252,)
# train==0 (6252,)
# X_train.shape, y_train.shape:(10628, 14)(10628,)
# X_valid.shape, y_valid.shape:(1876, 14)(1876,)
# all data ('nor gini:', 0.76932105974328802)
# train data ('nor gini:', 0.76121341160162481)
# valid data ('nor gini:', 0.7434613408740639)
# mean of all impurity:0.0
# pass node id shape:(3,)
# pass data shape:(916, 14) (165,)
# not pass data shape:(11588, 14) (42493,)
# all data shape:12504
# mean of all impurity:0.292184433399
# pass node id shape:(61,)
# pass test data shape: 782
# not pass test data shape: 6300
# pass test data ('nor gini:', 0.25353736505607388)
# train==1 (6087,)
# train==0 (22626,)
#
# layer: 3
# train==1 (6087,)
# train==0 (6087,)
# X_train.shape, y_train.shape:(10347, 14)(10347,)
# X_valid.shape, y_valid.shape:(1827, 14)(1827,)
# all data ('nor gini:', 0.75678957077364262)
# train data ('nor gini:', 0.75155506599601229)
# valid data ('nor gini:', 0.73397628708588092)
# mean of all impurity:0.0
# pass node id shape:(3,)
# pass data shape:(784, 14) (3,)
# not pass data shape:(11390, 14) (42084,)
# all data shape:12174
# mean of all impurity:0.301546041873
# pass node id shape:(70,)
# pass test data shape: 1011
# not pass test data shape: 5289
# pass test data ('nor gini:', 0.5875035340684196)
# train==1 (6084,)
# train==0 (21845,)
#
# layer: 4
# train==1 (6084,)
# train==0 (6084,)
# X_train.shape, y_train.shape:(10342, 14)(10342,)
# X_valid.shape, y_valid.shape:(1826, 14)(1826,)
# all data ('nor gini:', 0.73507185832705502)
# train data ('nor gini:', 0.73159178302779815)
# valid data ('nor gini:', 0.69373621139941599)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(502, 14) (2,)
# not pass data shape:(11666, 14) (42976,)
# all data shape:12168
# mean of all impurity:0.312884464528
# pass node id shape:(60,)
# pass test data shape: 572
# not pass test data shape: 4717
# pass test data ('nor gini:', 0.41122589531680454)
# train==1 (6082,)
# train==0 (21345,)
#
# layer: 5
# train==1 (6082,)
# train==0 (6082,)
# X_train.shape, y_train.shape:(10339, 14)(10339,)
# X_valid.shape, y_valid.shape:(1825, 14)(1825,)
# all data ('nor gini:', 0.74165853039264673)
# train data ('nor gini:', 0.73454603829630061)
# valid data ('nor gini:', 0.71386983340058785)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(446, 14) (0,)
# not pass data shape:(11718, 14) (43042,)
# all data shape:12164
# mean of all impurity:0.308378469981
# pass node id shape:(58,)
# pass test data shape: 96
# not pass test data shape: 4621
# pass test data ('nor gini:', 0.37383592017738365)
# train==1 (6082,)
# train==0 (20899,)
#
# layer: 6
# train==1 (6082,)
# train==0 (6082,)
# X_train.shape, y_train.shape:(10339, 14)(10339,)
# X_valid.shape, y_valid.shape:(1825, 14)(1825,)
# all data ('nor gini:', 0.72549783021278502)
# train data ('nor gini:', 0.71877630854674834)
# valid data ('nor gini:', 0.69082310101650612)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(307, 14) (0,)
# not pass data shape:(11857, 14) (43694,)
# all data shape:12164
# mean of all impurity:0.321008883099
# pass node id shape:(60,)
# pass test data shape: 419
# not pass test data shape: 4202
# pass test data ('nor gini:', 0.45382739609838857)
# train==1 (6082,)
# train==0 (20592,)
#
# layer: 7
# train==1 (6082,)
# train==0 (6082,)
# X_train.shape, y_train.shape:(10339, 14)(10339,)
# X_valid.shape, y_valid.shape:(1825, 14)(1825,)
# all data ('nor gini:', 0.72628910966976445)
# train data ('nor gini:', 0.72251455915772222)
# valid data ('nor gini:', 0.68389346861128741)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(392, 14) (1,)
# not pass data shape:(11772, 14) (43352,)
# all data shape:12164
# mean of all impurity:0.312690204063
# pass node id shape:(59,)
# pass test data shape: 79
# not pass test data shape: 4123
# pass test data ('nor gini:', 0.36617405582922824)
# train==1 (6081,)
# train==0 (20201,)
#
# layer: 8
# train==1 (6081,)
# train==0 (6081,)
# X_train.shape, y_train.shape:(10337, 14)(10337,)
# X_valid.shape, y_valid.shape:(1825, 14)(1825,)
# all data ('nor gini:', 0.72840343895480431)
# train data ('nor gini:', 0.72007238915971417)
# valid data ('nor gini:', 0.69992650025941083)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(238, 14) (1,)
# not pass data shape:(11924, 14) (43945,)
# all data shape:12162
# mean of all impurity:0.31893318355
# pass node id shape:(63,)
# pass test data shape: 182
# not pass test data shape: 3941
# pass test data ('nor gini:', -0.23044217687074822)
# train==1 (6080,)
# train==0 (19964,)
#
# layer: 9
# train==1 (6080,)
# train==0 (6080,)
# X_train.shape, y_train.shape:(10336, 14)(10336,)
# X_valid.shape, y_valid.shape:(1824, 14)(1824,)
# all data ('nor gini:', 0.71381551895775597)
# train data ('nor gini:', 0.70394557122180779)
# valid data ('nor gini:', 0.69014985380116944)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(242, 14) (0,)
# not pass data shape:(11918, 14) (43904,)
# all data shape:12160
# mean of all impurity:0.316598470328
# pass node id shape:(57,)
# pass test data shape: 70
# not pass test data shape: 3871
# pass test data ('nor gini:', 0.16176470588235295)
# train==1 (6080,)
# train==0 (19722,)
#
# layer: 10
# train==1 (6080,)
# train==0 (6080,)
# X_train.shape, y_train.shape:(10336, 14)(10336,)
# X_valid.shape, y_valid.shape:(1824, 14)(1824,)
# all data ('nor gini:', 0.71741835829293632)
# train data ('nor gini:', 0.70985169212299548)
# valid data ('nor gini:', 0.69081351954447534)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(193, 14) (1,)
# not pass data shape:(11967, 14) (44058,)
# all data shape:12160
# mean of all impurity:0.313628207939
# pass node id shape:(64,)
# pass test data shape: 6
# not pass test data shape: 3865
# pass test data ('nor gini:', 0.25)
# train==1 (6079,)
# train==0 (19530,)
#
# layer: 11
# train==1 (6079,)
# train==0 (6079,)
# X_train.shape, y_train.shape:(10334, 14)(10334,)
# X_valid.shape, y_valid.shape:(1824, 14)(1824,)
# all data ('nor gini:', 0.71550264014352249)
# train data ('nor gini:', 0.70731311378214201)
# valid data ('nor gini:', 0.69642582333025527)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(197, 14) (1,)
# not pass data shape:(11961, 14) (44072,)
# all data shape:12158
# mean of all impurity:0.325300179209
# pass node id shape:(63,)
# pass test data shape: 289
# not pass test data shape: 3576
# pass test data ('nor gini:', 0.40438871473354221)
# train==1 (6078,)
# train==0 (19334,)
#
# layer: 12
# train==1 (6078,)
# train==0 (6078,)
# X_train.shape, y_train.shape:(10332, 14)(10332,)
# X_valid.shape, y_valid.shape:(1824, 14)(1824,)
# all data ('nor gini:', 0.70883131552621659)
# train data ('nor gini:', 0.69952340334199192)
# valid data ('nor gini:', 0.68398930440135453)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(139, 14) (0,)
# not pass data shape:(12017, 14) (44229,)
# all data shape:12156
# mean of all impurity:0.333321540033
# pass node id shape:(57,)
# pass test data shape: 172
# not pass test data shape: 3404
# pass test data ('nor gini:', 0.25509036833676507)
# train==1 (6078,)
# train==0 (19195,)
#
# layer: 13
# train==1 (6078,)
# train==0 (6078,)
# X_train.shape, y_train.shape:(10332, 14)(10332,)
# X_valid.shape, y_valid.shape:(1824, 14)(1824,)
# all data ('nor gini:', 0.70546583132667862)
# train data ('nor gini:', 0.69193342395234692)
# valid data ('nor gini:', 0.69755357417666952)
# mean of all impurity:0.0172400756144
# pass node id shape:(1,)
# pass data shape:(137, 14) (5,)
# not pass data shape:(12019, 14) (44201,)
# all data shape:12156
# mean of all impurity:0.33704788872
# pass node id shape:(62,)
# pass test data shape: 286
# not pass test data shape: 3118
# pass test data ('nor gini:', 0.34267621717014424)
# train==1 (6073,)
# train==0 (19063,)
#
# layer: 14
# train==1 (6073,)
# train==0 (6073,)
# X_train.shape, y_train.shape:(10324, 14)(10324,)
# X_valid.shape, y_valid.shape:(1822, 14)(1822,)
# all data ('nor gini:', 0.71516330119231852)
# train data ('nor gini:', 0.70456429056192704)
# valid data ('nor gini:', 0.69527220060704586)
# mean of all impurity:0.0107523739956
# pass node id shape:(1,)
# pass data shape:(219, 14) (3,)
# not pass data shape:(11927, 14) (43905,)
# all data shape:12146
# mean of all impurity:0.317374821545
# pass node id shape:(60,)
# pass test data shape: 9
# not pass test data shape: 3109
# pass test data ('nor gini:', 0.11111111111111131)
# train==1 (6070,)
# train==0 (18847,)
#
# layer: 15
# train==1 (6070,)
# train==0 (6070,)
# X_train.shape, y_train.shape:(10319, 14)(10319,)
# X_valid.shape, y_valid.shape:(1821, 14)(1821,)
# all data ('nor gini:', 0.70785411278087329)
# train data ('nor gini:', 0.70056197418224486)
# valid data ('nor gini:', 0.67470114956393779)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(123, 14) (2,)
# not pass data shape:(12017, 14) (44212,)
# all data shape:12140
# mean of all impurity:0.322361367332
# pass node id shape:(61,)
# pass test data shape: 32
# not pass test data shape: 3077
# pass test data ('nor gini:', 0.83333333333333337)
# train==1 (6068,)
# train==0 (18726,)
#
# layer: 16
# train==1 (6068,)
# train==0 (6068,)
# X_train.shape, y_train.shape:(10315, 14)(10315,)
# X_valid.shape, y_valid.shape:(1821, 14)(1821,)
# all data ('nor gini:', 0.69876561570493756)
# train data ('nor gini:', 0.69366513424947529)
# valid data ('nor gini:', 0.65840219056464955)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(129, 14) (1,)
# not pass data shape:(12007, 14) (44155,)
# all data shape:12136
# mean of all impurity:0.338099159576
# pass node id shape:(60,)
# pass test data shape: 34
# not pass test data shape: 3043
# pass test data ('nor gini:', 0.40659340659340665)
# train==1 (6067,)
# train==0 (18598,)
#
# layer: 17
# train==1 (6067,)
# train==0 (6067,)
# X_train.shape, y_train.shape:(10313, 14)(10313,)
# X_valid.shape, y_valid.shape:(1821, 14)(1821,)
# all data ('nor gini:', 0.71028400540973025)
# train data ('nor gini:', 0.70552600252761488)
# valid data ('nor gini:', 0.65945887263121095)
# mean of all impurity:0.0
# pass node id shape:(2,)
# pass data shape:(319, 14) (1,)
# not pass data shape:(11815, 14) (43393,)
# all data shape:12134
# mean of all impurity:0.32301276096
# pass node id shape:(59,)
# pass test data shape: 3
# not pass test data shape: 3040
# pass test data ('nor gini:', nan)
# train==1 (6066,)
# train==0 (18280,)
#
# layer: 18
# train==1 (6066,)
# train==0 (6066,)
# X_train.shape, y_train.shape:(10312, 14)(10312,)
# X_valid.shape, y_valid.shape:(1820, 14)(1820,)
# all data ('nor gini:', 0.69192873337783767)
# train data ('nor gini:', 0.68818457606012806)
# valid data ('nor gini:', 0.64761260717304647)
# mean of all impurity:0.015872
# pass node id shape:(1,)
# pass data shape:(137, 14) (1,)
# not pass data shape:(11995, 14) (44368,)
# all data shape:12132
# mean of all impurity:0.330064042904
# pass node id shape:(64,)
# pass test data shape: 66
# not pass test data shape: 2974
# pass test data ('nor gini:', 0.28472222222222232)
# train==1 (6065,)
# train==0 (18144,)
#
# layer: 19
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in double_scalars
# train==1 (6065,)
# train==0 (6065,)
# X_train.shape, y_train.shape:(10310, 14)(10310,)
# X_valid.shape, y_valid.shape:(1820, 14)(1820,)
# all data ('nor gini:', 0.69844948479953006)
# train data ('nor gini:', 0.69007818725240155)
# valid data ('nor gini:', 0.66401159280280153)
# mean of all impurity:0.012421875
# pass node id shape:(1,)
# pass data shape:(187, 14) (4,)
# not pass data shape:(11943, 14) (44090,)
# all data shape:12130
# mean of all impurity:0.331603397852
# pass node id shape:(59,)
# pass test data shape: 18
# not pass test data shape: 2956
# pass test data ('nor gini:', 0.5)
# train==1 (6061,)
# train==0 (17961,)
#
# layer: 20
# train==1 (6061,)
# train==0 (6061,)
# X_train.shape, y_train.shape:(10303, 14)(10303,)
# X_valid.shape, y_valid.shape:(1819, 14)(1819,)
# all data ('nor gini:', 0.69187647086061022)
# train data ('nor gini:', 0.67813273609056202)
# valid data ('nor gini:', 0.66895634618406863)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(130, 14) (2,)
# not pass data shape:(11992, 14) (44349,)
# all data shape:12122
# mean of all impurity:0.326956172082
# pass node id shape:(59,)
# pass test data shape: 44
# not pass test data shape: 2912
# pass test data ('nor gini:', -0.0024813895781638775)
# train==1 (6059,)
# train==0 (17833,)
#
# layer: 21
# train==1 (6059,)
# train==0 (6059,)
# X_train.shape, y_train.shape:(10300, 14)(10300,)
# X_valid.shape, y_valid.shape:(1818, 14)(1818,)
# all data ('nor gini:', 0.68597300664606808)
# train data ('nor gini:', 0.68534074842115178)
# valid data ('nor gini:', 0.62103449068779248)
# mean of all impurity:0.0175424857076
# pass node id shape:(1,)
# pass data shape:(131, 14) (2,)
# not pass data shape:(11987, 14) (44401,)
# all data shape:12118
# mean of all impurity:0.338274147089
# pass node id shape:(57,)
# pass test data shape: 67
# not pass test data shape: 2845
# pass test data ('nor gini:', 0.43428571428571411)
# train==1 (6057,)
# train==0 (17704,)
#
# layer: 22
# train==1 (6057,)
# train==0 (6057,)
# X_train.shape, y_train.shape:(10296, 14)(10296,)
# X_valid.shape, y_valid.shape:(1818, 14)(1818,)
# all data ('nor gini:', 0.68524568304371902)
# train data ('nor gini:', 0.68273373867779452)
# valid data ('nor gini:', 0.63082050779335364)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(117, 14) (1,)
# not pass data shape:(11997, 14) (44337,)
# all data shape:12114
# mean of all impurity:0.337462351307
# pass node id shape:(57,)
# pass test data shape: 21
# not pass test data shape: 2824
# pass test data ('nor gini:', 0.55769230769230771)
# train==1 (6056,)
# train==0 (17588,)
#
# layer: 23
# train==1 (6056,)
# train==0 (6056,)
# X_train.shape, y_train.shape:(10295, 14)(10295,)
# X_valid.shape, y_valid.shape:(1817, 14)(1817,)
# all data ('nor gini:', 0.68532555680229801)
# train data ('nor gini:', 0.68131472396092563)
# valid data ('nor gini:', 0.63617132638373997)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(126, 14) (0,)
# not pass data shape:(11986, 14) (44365,)
# all data shape:12112
# mean of all impurity:0.33516694173
# pass node id shape:(63,)
# pass test data shape: 103
# not pass test data shape: 2721
# pass test data ('nor gini:', 0.00080971659919030624)
# train==1 (6056,)
# train==0 (17462,)
#
# layer: 24
# train==1 (6056,)
# train==0 (6056,)
# X_train.shape, y_train.shape:(10295, 14)(10295,)
# X_valid.shape, y_valid.shape:(1817, 14)(1817,)
# all data ('nor gini:', 0.67565284556817995)
# train data ('nor gini:', 0.66602002146979822)
# valid data ('nor gini:', 0.63805896008103014)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(143, 14) (0,)
# not pass data shape:(11969, 14) (44227,)
# all data shape:12112
# mean of all impurity:0.341747959929
# pass node id shape:(60,)
# pass test data shape: 58
# not pass test data shape: 2663
# pass test data ('nor gini:', 0.1764705882352941)
# train==1 (6056,)
# train==0 (17319,)
#
# layer: 25
# train==1 (6056,)
# train==0 (6056,)
# X_train.shape, y_train.shape:(10295, 14)(10295,)
# X_valid.shape, y_valid.shape:(1817, 14)(1817,)
# all data ('nor gini:', 0.68512956570904049)
# train data ('nor gini:', 0.66867181778780749)
# valid data ('nor gini:', 0.65618654376450847)
# mean of all impurity:0.0175424857076
# pass node id shape:(1,)
# pass data shape:(131, 14) (5,)
# not pass data shape:(11981, 14) (44330,)
# all data shape:12112
# mean of all impurity:0.334106266459
# pass node id shape:(55,)
# pass test data shape: 7
# not pass test data shape: 2656
# pass test data ('nor gini:', 0.33333333333333331)
# train==1 (6051,)
# train==0 (17193,)
#
# layer: 26
# train==1 (6051,)
# train==0 (6051,)
# X_train.shape, y_train.shape:(10286, 14)(10286,)
# X_valid.shape, y_valid.shape:(1816, 14)(1816,)
# all data ('nor gini:', 0.67463837718728659)
# train data ('nor gini:', 0.67497882550122323)
# valid data ('nor gini:', 0.59481068912651114)
# mean of all impurity:0.0360239037118
# pass node id shape:(1,)
# pass data shape:(124, 14) (3,)
# not pass data shape:(11978, 14) (44280,)
# all data shape:12102
# mean of all impurity:0.343389743073
# pass node id shape:(57,)
# pass test data shape: 75
# not pass test data shape: 2581
# pass test data ('nor gini:', 0.066666666666666666)
# train==1 (6048,)
# train==0 (17072,)
#
# layer: 27
# train==1 (6048,)
# train==0 (6048,)
# X_train.shape, y_train.shape:(10281, 14)(10281,)
# X_valid.shape, y_valid.shape:(1815, 14)(1815,)
# all data ('nor gini:', 0.68775495988004265)
# train data ('nor gini:', 0.67610368162562817)
# valid data ('nor gini:', 0.62772901903452838)
# mean of all impurity:0.0281632653061
# pass node id shape:(1,)
# pass data shape:(164, 14) (4,)
# not pass data shape:(11932, 14) (44184,)
# all data shape:12096
# mean of all impurity:0.335631468579
# pass node id shape:(56,)
# pass test data shape: 110
# not pass test data shape: 2471
# pass test data ('nor gini:', 0.30012249897917531)
# train==1 (6044,)
# train==0 (16912,)
#
# layer: 28
# train==1 (6044,)
# train==0 (6044,)
# X_train.shape, y_train.shape:(10274, 14)(10274,)
# X_valid.shape, y_valid.shape:(1814, 14)(1814,)
# all data ('nor gini:', 0.67702784915911174)
# train data ('nor gini:', 0.66962255799048442)
# valid data ('nor gini:', 0.64895356342741572)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(145, 14) (5,)
# not pass data shape:(11943, 14) (44204,)
# all data shape:12088
# mean of all impurity:0.334864191564
# pass node id shape:(56,)
# pass test data shape: 4
# not pass test data shape: 2467
# pass test data ('nor gini:', -0.33333333333333331)
# train==1 (6039,)
# train==0 (16772,)
#
# layer: 29
# train==1 (6039,)
# train==0 (6039,)
# X_train.shape, y_train.shape:(10266, 14)(10266,)
# X_valid.shape, y_valid.shape:(1812, 14)(1812,)
# all data ('nor gini:', 0.67762603736967086)
# train data ('nor gini:', 0.66560718095617433)
# valid data ('nor gini:', 0.65397229166362114)
# mean of all impurity:0.0142849748978
# pass node id shape:(1,)
# pass data shape:(161, 14) (157,)
# not pass data shape:(11917, 14) (43917,)
# all data shape:12078
# mean of all impurity:0.33938143567
# pass node id shape:(53,)
# pass test data shape: 125
# not pass test data shape: 2342
# pass test data ('nor gini:', 0.1045751633986927)
# train==1 (5882,)
# train==0 (16768,)
#
# layer: 30
# train==1 (5882,)
# train==0 (5882,)
# X_train.shape, y_train.shape:(9999, 14)(9999,)
# X_valid.shape, y_valid.shape:(1765, 14)(1765,)
# all data ('nor gini:', 0.66434049626792624)
# train data ('nor gini:', 0.65781036207241461)
# valid data ('nor gini:', 0.62592481311135262)
# mean of all impurity:0.0336979591837
# pass node id shape:(1,)
# pass data shape:(211, 14) (4,)
# not pass data shape:(11553, 14) (42706,)
# all data shape:11764
# mean of all impurity:0.352308226926
# pass node id shape:(53,)
# pass test data shape: 27
# not pass test data shape: 2315
# pass test data ('nor gini:', 0.47999999999999998)
# train==1 (5878,)
# train==0 (16561,)
#
# layer: 31
# train==1 (5878,)
# train==0 (5878,)
# X_train.shape, y_train.shape:(9992, 14)(9992,)
# X_valid.shape, y_valid.shape:(1764, 14)(1764,)
# all data ('nor gini:', 0.66710472588776615)
# train data ('nor gini:', 0.66378667385469636)
# valid data ('nor gini:', 0.6208010036970194)
# mean of all impurity:0.0253122945431
# pass node id shape:(1,)
# pass data shape:(183, 14) (3,)
# not pass data shape:(11573, 14) (42766,)
# all data shape:11756
# mean of all impurity:0.343917928973
# pass node id shape:(60,)
# pass test data shape: 73
# not pass test data shape: 2242
# pass test data ('nor gini:', -0.16366612111292964)
# train==1 (5875,)
# train==0 (16381,)
#
# layer: 32
# train==1 (5875,)
# train==0 (5875,)
# X_train.shape, y_train.shape:(9987, 14)(9987,)
# X_valid.shape, y_valid.shape:(1763, 14)(1763,)
# all data ('nor gini:', 0.66385490629243993)
# train data ('nor gini:', 0.65491038675611613)
# valid data ('nor gini:', 0.64091516288694816)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(130, 14) (0,)
# not pass data shape:(11620, 14) (43009,)
# all data shape:11750
# mean of all impurity:0.34621784108
# pass node id shape:(59,)
# pass test data shape: 149
# not pass test data shape: 2093
# pass test data ('nor gini:', 0.056827820186598911)
# train==1 (5875,)
# train==0 (16251,)
#
# layer: 33
# train==1 (5875,)
# train==0 (5875,)
# X_train.shape, y_train.shape:(9987, 14)(9987,)
# X_valid.shape, y_valid.shape:(1763, 14)(1763,)
# all data ('nor gini:', 0.66504885830692617)
# train data ('nor gini:', 0.65731078375564778)
# valid data ('nor gini:', 0.62394310732238434)
# mean of all impurity:0.0570934256055
# pass node id shape:(1,)
# pass data shape:(164, 14) (5,)
# not pass data shape:(11586, 14) (42846,)
# all data shape:11750
# mean of all impurity:0.348416371164
# pass node id shape:(60,)
# pass test data shape: 0
# not pass test data shape: 2093
# pass test data ('nor gini:', nan)
# train==1 (5870,)
# train==0 (16092,)
#
# layer: 34
# train==1 (5870,)
# train==0 (5870,)
# X_train.shape, y_train.shape:(9979, 14)(9979,)
# X_valid.shape, y_valid.shape:(1761, 14)(1761,)
# all data ('nor gini:', 0.66192727726522127)
# train data ('nor gini:', 0.65583586495500545)
# valid data ('nor gini:', 0.62174440202249526)
# mean of all impurity:0.0151506322475
# pass node id shape:(1,)
# pass data shape:(154, 14) (2,)
# not pass data shape:(11586, 14) (42903,)
# all data shape:11740
# mean of all impurity:0.356812089365
# pass node id shape:(54,)
# pass test data shape: 0
# not pass test data shape: 2093
# pass test data ('nor gini:', nan)
# train==1 (5868,)
# train==0 (15940,)
#
# layer: 35
# train==1 (5868,)
# train==0 (5868,)
# X_train.shape, y_train.shape:(9975, 14)(9975,)
# X_valid.shape, y_valid.shape:(1761, 14)(1761,)
# all data ('nor gini:', 0.65751172465451002)
# train data ('nor gini:', 0.65473430598787008)
# valid data ('nor gini:', 0.58057733979981452)
# mean of all impurity:0.0360239037118
# pass node id shape:(1,)
# pass data shape:(125, 14) (2,)
# not pass data shape:(11611, 14) (43153,)
# all data shape:11736
# mean of all impurity:0.339173008554
# pass node id shape:(59,)
# pass test data shape: 0
# not pass test data shape: 2093
# pass test data ('nor gini:', nan)
# train==1 (5866,)
# train==0 (15817,)
#
# layer: 36
# train==1 (5866,)
# train==0 (5866,)
# X_train.shape, y_train.shape:(9972, 14)(9972,)
# X_valid.shape, y_valid.shape:(1760, 14)(1760,)
# all data ('nor gini:', 0.6534074614916684)
# train data ('nor gini:', 0.65125150260279541)
# valid data ('nor gini:', 0.58046745867768601)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(121, 14) (2,)
# not pass data shape:(11611, 14) (43170,)
# all data shape:11732
# mean of all impurity:0.351918977002
# pass node id shape:(53,)
# pass test data shape: 19
# not pass test data shape: 2074
# pass test data ('nor gini:', 0.88888888888888884)
# train==1 (5864,)
# train==0 (15698,)
#
# layer: 37
# train==1 (5864,)
# train==0 (5864,)
# X_train.shape, y_train.shape:(9968, 14)(9968,)
# X_valid.shape, y_valid.shape:(1760, 14)(1760,)
# all data ('nor gini:', 0.64860031100580884)
# train data ('nor gini:', 0.63923455539266572)
# valid data ('nor gini:', 0.63059400826446266)
# mean of all impurity:0.0392
# pass node id shape:(1,)
# pass data shape:(122, 14) (5,)
# not pass data shape:(11606, 14) (43051,)
# all data shape:11728
# mean of all impurity:0.354108359276
# pass node id shape:(64,)
# pass test data shape: 0
# not pass test data shape: 2074
# pass test data ('nor gini:', nan)
# train==1 (5859,)
# train==0 (15581,)
#
# layer: 38
# train==1 (5859,)
# train==0 (5859,)
# X_train.shape, y_train.shape:(9960, 14)(9960,)
# X_valid.shape, y_valid.shape:(1758, 14)(1758,)
# all data ('nor gini:', 0.65085261161328323)
# train data ('nor gini:', 0.64477532620441602)
# valid data ('nor gini:', 0.59885380144206679)
# mean of all impurity:0.0521364795918
# pass node id shape:(1,)
# pass data shape:(132, 14) (4,)
# not pass data shape:(11586, 14) (43021,)
# all data shape:11718
# mean of all impurity:0.347509939872
# pass node id shape:(54,)
# pass test data shape: 15
# not pass test data shape: 2059
# pass test data ('nor gini:', 0.43999999999999984)
# train==1 (5855,)
# train==0 (15453,)
#
# layer: 39
# train==1 (5855,)
# train==0 (5855,)
# X_train.shape, y_train.shape:(9953, 14)(9953,)
# X_valid.shape, y_valid.shape:(1757, 14)(1757,)
# all data ('nor gini:', 0.64343359044836035)
# train data ('nor gini:', 0.64138493662487306)
# valid data ('nor gini:', 0.57564896950096045)
# mean of all impurity:0.0173899661434
# pass node id shape:(1,)
# pass data shape:(129, 14) (1,)
# not pass data shape:(11581, 14) (42913,)
# all data shape:11710
# mean of all impurity:0.364291964716
# pass node id shape:(59,)
# pass test data shape: 12
# not pass test data shape: 2047
# pass test data ('nor gini:', -0.25)
# train==1 (5854,)
# train==0 (15325,)
#
# layer: 40
# train==1 (5854,)
# train==0 (5854,)
# X_train.shape, y_train.shape:(9951, 14)(9951,)
# X_valid.shape, y_valid.shape:(1757, 14)(1757,)
# all data ('nor gini:', 0.64060479059459485)
# train data ('nor gini:', 0.63683166637043731)
# valid data ('nor gini:', 0.57422106815313523)
# mean of all impurity:0.0475907198096
# pass node id shape:(1,)
# pass data shape:(202, 14) (5,)
# not pass data shape:(11506, 14) (42788,)
# all data shape:11708
# mean of all impurity:0.361220253621
# pass node id shape:(53,)
# pass test data shape: 109
# not pass test data shape: 1938
# pass test data ('nor gini:', -0.012765957446808541)
# train==1 (5849,)
# train==0 (15128,)
#
# layer: 41
# train==1 (5849,)
# train==0 (5849,)
# X_train.shape, y_train.shape:(9943, 14)(9943,)
# X_valid.shape, y_valid.shape:(1755, 14)(1755,)
# all data ('nor gini:', 0.65303285357159568)
# train data ('nor gini:', 0.64612297585043943)
# valid data ('nor gini:', 0.60865240011116795)
# mean of all impurity:0.0602432280061
# pass node id shape:(1,)
# pass data shape:(228, 14) (9,)
# not pass data shape:(11470, 14) (42594,)
# all data shape:11698
# mean of all impurity:0.36293059286
# pass node id shape:(59,)
# pass test data shape: 7
# not pass test data shape: 1931
# pass test data ('nor gini:', -0.39999999999999997)
# train==1 (5840,)
# train==0 (14909,)
#
# layer: 42
# train==1 (5840,)
# train==0 (5840,)
# X_train.shape, y_train.shape:(9928, 14)(9928,)
# X_valid.shape, y_valid.shape:(1752, 14)(1752,)
# all data ('nor gini:', 0.64336953462188018)
# train data ('nor gini:', 0.63545001853798599)
# valid data ('nor gini:', 0.59997967098267357)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(120, 14) (2,)
# not pass data shape:(11560, 14) (42880,)
# all data shape:11680
# mean of all impurity:0.354001961352
# pass node id shape:(57,)
# pass test data shape: 25
# not pass test data shape: 1906
# pass test data ('nor gini:', -0.015873015873015817)
# train==1 (5838,)
# train==0 (14791,)
#
# layer: 43
# train==1 (5838,)
# train==0 (5838,)
# X_train.shape, y_train.shape:(9924, 14)(9924,)
# X_valid.shape, y_valid.shape:(1752, 14)(1752,)
# all data ('nor gini:', 0.64072453679986552)
# train data ('nor gini:', 0.62884288996209947)
# valid data ('nor gini:', 0.61930526886428539)
# mean of all impurity:0.0525931336742
# pass node id shape:(1,)
# pass data shape:(130, 14) (3,)
# not pass data shape:(11546, 14) (43011,)
# all data shape:11676
# mean of all impurity:0.360167625806
# pass node id shape:(54,)
# pass test data shape: 9
# not pass test data shape: 1897
# pass test data ('nor gini:', -0.25)
# train==1 (5835,)
# train==0 (14664,)
#
# layer: 44
# train==1 (5835,)
# train==0 (5835,)
# X_train.shape, y_train.shape:(9919, 14)(9919,)
# X_valid.shape, y_valid.shape:(1751, 14)(1751,)
# all data ('nor gini:', 0.64048147829962643)
# train data ('nor gini:', 0.63734363717971243)
# valid data ('nor gini:', 0.57646183953033248)
# mean of all impurity:0.0341776937618
# pass node id shape:(1,)
# pass data shape:(127, 14) (4,)
# not pass data shape:(11543, 14) (42837,)
# all data shape:11670
# mean of all impurity:0.358229924867
# pass node id shape:(56,)
# pass test data shape: 4
# not pass test data shape: 1893
# pass test data ('nor gini:', 1.0)
# train==1 (5831,)
# train==0 (14541,)
#
# layer: 45
# train==1 (5831,)
# train==0 (5831,)
# X_train.shape, y_train.shape:(9912, 14)(9912,)
# X_valid.shape, y_valid.shape:(1750, 14)(1750,)
# all data ('nor gini:', 0.63153607965468583)
# train data ('nor gini:', 0.62739720517144915)
# valid data ('nor gini:', 0.56333975510204104)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(118, 14) (0,)
# not pass data shape:(11544, 14) (43027,)
# all data shape:11662
# mean of all impurity:0.371864829808
# pass node id shape:(52,)
# pass test data shape: 28
# not pass test data shape: 1865
# pass test data ('nor gini:', -0.38775510204081631)
# train==1 (5831,)
# train==0 (14423,)
#
# layer: 46
# train==1 (5831,)
# train==0 (5831,)
# X_train.shape, y_train.shape:(9912, 14)(9912,)
# X_valid.shape, y_valid.shape:(1750, 14)(1750,)
# all data ('nor gini:', 0.63748604030386424)
# train data ('nor gini:', 0.62177272996721422)
# valid data ('nor gini:', 0.60846367346938757)
# mean of all impurity:0.0314056133997
# pass node id shape:(1,)
# pass data shape:(219, 14) (4,)
# not pass data shape:(11443, 14) (42636,)
# all data shape:11662
# mean of all impurity:0.371390981154
# pass node id shape:(51,)
# pass test data shape: 37
# not pass test data shape: 1828
# pass test data ('nor gini:', -0.13725490196078424)
# train==1 (5827,)
# train==0 (14208,)
#
# layer: 47
# train==1 (5827,)
# train==0 (5827,)
# X_train.shape, y_train.shape:(9905, 14)(9905,)
# X_valid.shape, y_valid.shape:(1749, 14)(1749,)
# all data ('nor gini:', 0.62791504924216568)
# train data ('nor gini:', 0.6236360072239634)
# valid data ('nor gini:', 0.57669565217391328)
# mean of all impurity:0.0470314994919
# pass node id shape:(1,)
# pass data shape:(195, 14) (6,)
# not pass data shape:(11459, 14) (42753,)
# all data shape:11654
# mean of all impurity:0.373116010906
# pass node id shape:(56,)
# pass test data shape: 13
# not pass test data shape: 1815
# pass test data ('nor gini:', 0.0)
# train==1 (5821,)
# train==0 (14019,)
#
# layer: 48
# train==1 (5821,)
# train==0 (5821,)
# X_train.shape, y_train.shape:(9895, 14)(9895,)
# X_valid.shape, y_valid.shape:(1747, 14)(1747,)
# all data ('nor gini:', 0.61936818574856534)
# train data ('nor gini:', 0.61024842309891481)
# valid data ('nor gini:', 0.5791727937803568)
# mean of all impurity:0.0312421264802
# pass node id shape:(1,)
# pass data shape:(149, 14) (5,)
# not pass data shape:(11493, 14) (42895,)
# all data shape:11642
# mean of all impurity:0.363313626301
# pass node id shape:(60,)
# pass test data shape: 12
# not pass test data shape: 1803
# pass test data ('nor gini:', 0.0625)
# train==1 (5816,)
# train==0 (13875,)
#
# layer: 49
# train==1 (5816,)
# train==0 (5816,)
# X_train.shape, y_train.shape:(9887, 14)(9887,)
# X_valid.shape, y_valid.shape:(1745, 14)(1745,)
# all data ('nor gini:', 0.62065935596722221)
# train data ('nor gini:', 0.61544389208497907)
# valid data ('nor gini:', 0.57202307765061944)
# mean of all impurity:0.0713305898491
# pass node id shape:(1,)
# pass data shape:(120, 14) (116,)
# not pass data shape:(11512, 14) (42871,)
# all data shape:11632
# mean of all impurity:0.374200158607
# pass node id shape:(53,)
# pass test data shape: 17
# not pass test data shape: 1786
# pass test data ('nor gini:', -0.37500000000000006)
# train==1 (5700,)
# train==0 (13871,)
#
# layer: 50
# train==1 (5700,)
# train==0 (5700,)
# X_train.shape, y_train.shape:(9690, 14)(9690,)
# X_valid.shape, y_valid.shape:(1710, 14)(1710,)
# all data ('nor gini:', 0.6162275777162205)
# train data ('nor gini:', 0.60611339555103994)
# valid data ('nor gini:', 0.56875072671933247)
# mean of all impurity:0.0377218934911
# pass node id shape:(1,)
# pass data shape:(178, 14) (4,)
# not pass data shape:(11222, 14) (41793,)
# all data shape:11400
# mean of all impurity:0.380157656224
# pass node id shape:(50,)
# pass test data shape: 21
# not pass test data shape: 1765
# pass test data ('nor gini:', 0.42105263157894735)
# train==1 (5696,)
# train==0 (13697,)
#
# layer: 51
# train==1 (5696,)
# train==0 (5696,)
# X_train.shape, y_train.shape:(9683, 14)(9683,)
# X_valid.shape, y_valid.shape:(1709, 14)(1709,)
# all data ('nor gini:', 0.61255798224261448)
# train data ('nor gini:', 0.60093816917847109)
# valid data ('nor gini:', 0.56603530684635062)
# mean of all impurity:0.0360239037118
# pass node id shape:(1,)
# pass data shape:(132, 14) (4,)
# not pass data shape:(11260, 14) (42052,)
# all data shape:11392
# mean of all impurity:0.365050970939
# pass node id shape:(48,)
# pass test data shape: 29
# not pass test data shape: 1736
# pass test data ('nor gini:', 0.14000000000000001)
# train==1 (5692,)
# train==0 (13569,)
#
# layer: 52
# train==1 (5692,)
# train==0 (5692,)
# X_train.shape, y_train.shape:(9676, 14)(9676,)
# X_valid.shape, y_valid.shape:(1708, 14)(1708,)
# all data ('nor gini:', 0.61306334691241016)
# train data ('nor gini:', 0.60577339961080456)
# valid data ('nor gini:', 0.56162212264642497)
# mean of all impurity:0.0660384250128
# pass node id shape:(1,)
# pass data shape:(140, 14) (4,)
# not pass data shape:(11244, 14) (41905,)
# all data shape:11384
# mean of all impurity:0.380803970861
# pass node id shape:(59,)
# pass test data shape: 20
# not pass test data shape: 1716
# pass test data ('nor gini:', 0.34375)
# train==1 (5688,)
# train==0 (13433,)
#
# layer: 53
# train==1 (5688,)
# train==0 (5688,)
# X_train.shape, y_train.shape:(9669, 14)(9669,)
# X_valid.shape, y_valid.shape:(1707, 14)(1707,)
# all data ('nor gini:', 0.61073390126226201)
# train data ('nor gini:', 0.59897289066287185)
# valid data ('nor gini:', 0.56991579519590607)
# mean of all impurity:0.0287708455432
# pass node id shape:(1,)
# pass data shape:(167, 14) (3,)
# not pass data shape:(11209, 14) (42005,)
# all data shape:11376
# mean of all impurity:0.368146904284
# pass node id shape:(51,)
# pass test data shape: 5
# not pass test data shape: 1711
# pass test data ('nor gini:', -0.5)
# train==1 (5685,)
# train==0 (13269,)
#
# layer: 54
# train==1 (5685,)
# train==0 (5685,)
# X_train.shape, y_train.shape:(9664, 14)(9664,)
# X_valid.shape, y_valid.shape:(1706, 14)(1706,)
# all data ('nor gini:', 0.60196093811036622)
# train data ('nor gini:', 0.59205993569361004)
# valid data ('nor gini:', 0.5578037105093534)
# mean of all impurity:0.0434567901235
# pass node id shape:(1,)
# pass data shape:(158, 14) (4,)
# not pass data shape:(11212, 14) (42121,)
# all data shape:11370
# mean of all impurity:0.383532240338
# pass node id shape:(47,)
# pass test data shape: 143
# not pass test data shape: 1568
# pass test data ('nor gini:', 0.089750127485976564)
# train==1 (5681,)
# train==0 (13115,)
#
# layer: 55
# train==1 (5681,)
# train==0 (5681,)
# X_train.shape, y_train.shape:(9657, 14)(9657,)
# X_valid.shape, y_valid.shape:(1705, 14)(1705,)
# all data ('nor gini:', 0.59189621562854111)
# train data ('nor gini:', 0.58310576307907724)
# valid data ('nor gini:', 0.55685264380342236)
# mean of all impurity:0.0719713512097
# pass node id shape:(1,)
# pass data shape:(125, 14) (6,)
# not pass data shape:(11237, 14) (42156,)
# all data shape:11362
# mean of all impurity:0.385045715227
# pass node id shape:(56,)
# pass test data shape: 11
# not pass test data shape: 1557
# pass test data ('nor gini:', -0.14285714285714288)
# train==1 (5675,)
# train==0 (12996,)
#
# layer: 56
# train==1 (5675,)
# train==0 (5675,)
# X_train.shape, y_train.shape:(9647, 14)(9647,)
# X_valid.shape, y_valid.shape:(1703, 14)(1703,)
# all data ('nor gini:', 0.58261434143880142)
# train data ('nor gini:', 0.57711425593712284)
# valid data ('nor gini:', 0.51825248395977119)
# mean of all impurity:0.0726237095052
# pass node id shape:(1,)
# pass data shape:(123, 14) (118,)
# not pass data shape:(11227, 14) (42036,)
# all data shape:11350
# mean of all impurity:0.375848160768
# pass node id shape:(55,)
# pass test data shape: 17
# not pass test data shape: 1540
# pass test data ('nor gini:', -0.066666666666666721)
# train==1 (5557,)
# train==0 (12991,)
#
# layer: 57
# train==1 (5557,)
# train==0 (5557,)
# X_train.shape, y_train.shape:(9446, 14)(9446,)
# X_valid.shape, y_valid.shape:(1668, 14)(1668,)
# all data ('nor gini:', 0.58244319856358673)
# train data ('nor gini:', 0.58014857310545165)
# valid data ('nor gini:', 0.50470415034878546)
# mean of all impurity:0.0941084207431
# pass node id shape:(1,)
# pass data shape:(125, 14) (8,)
# not pass data shape:(10989, 14) (41368,)
# all data shape:11114
# mean of all impurity:0.380506867328
# pass node id shape:(62,)
# pass test data shape: 72
# not pass test data shape: 1468
# pass test data ('nor gini:', 0.2385026737967916)
# train==1 (5549,)
# train==0 (12874,)
#
# layer: 58
# train==1 (5549,)
# train==0 (5549,)
# X_train.shape, y_train.shape:(9433, 14)(9433,)
# X_valid.shape, y_valid.shape:(1665, 14)(1665,)
# all data ('nor gini:', 0.58908761572752089)
# train data ('nor gini:', 0.58081680989645834)
# valid data ('nor gini:', 0.55119644011450752)
# mean of all impurity:0.0178556935314
# pass node id shape:(1,)
# pass data shape:(131, 14) (2,)
# not pass data shape:(10967, 14) (41255,)
# all data shape:11098
# mean of all impurity:0.387821148559
# pass node id shape:(54,)
# pass test data shape: 18
# not pass test data shape: 1450
# pass test data ('nor gini:', 0.01538461538461533)
# train==1 (5547,)
# train==0 (12745,)
#
# layer: 59
# train==1 (5547,)
# train==0 (5547,)
# X_train.shape, y_train.shape:(9429, 14)(9429,)
# X_valid.shape, y_valid.shape:(1665, 14)(1665,)
# all data ('nor gini:', 0.59585148906492846)
# train data ('nor gini:', 0.57261990298971832)
# valid data ('nor gini:', 0.57641229568750596)
# mean of all impurity:0.0768
# pass node id shape:(1,)
# pass data shape:(116, 14) (4,)
# not pass data shape:(10978, 14) (41244,)
# all data shape:11094
# mean of all impurity:0.37323507463
# pass node id shape:(51,)
# pass test data shape: 4
# not pass test data shape: 1446
# pass test data ('nor gini:', 1.0)
# train==1 (5543,)
# train==0 (12633,)
#
# layer: 60
# train==1 (5543,)
# train==0 (5543,)
# X_train.shape, y_train.shape:(9423, 14)(9423,)
# X_valid.shape, y_valid.shape:(1663, 14)(1663,)
# all data ('nor gini:', 0.58513924673803919)
# train data ('nor gini:', 0.5702224393366101)
# valid data ('nor gini:', 0.57661644913449972)
# mean of all impurity:0.0807809551459
# pass node id shape:(1,)
# pass data shape:(195, 14) (185,)
# not pass data shape:(10891, 14) (40771,)
# all data shape:11086
# mean of all impurity:0.386957290051
# pass node id shape:(51,)
# pass test data shape: 24
# not pass test data shape: 1422
# pass test data ('nor gini:', 0.10924369747899161)
# train==1 (5358,)
# train==0 (12623,)
#
# layer: 61
# train==1 (5358,)
# train==0 (5358,)
# X_train.shape, y_train.shape:(9108, 14)(9108,)
# X_valid.shape, y_valid.shape:(1608, 14)(1608,)
# all data ('nor gini:', 0.56945843001314878)
# train data ('nor gini:', 0.55925131284585938)
# valid data ('nor gini:', 0.52882044998886157)
# mean of all impurity:0.118048236096
# pass node id shape:(1,)
# pass data shape:(151, 14) (13,)
# not pass data shape:(10565, 14) (39719,)
# all data shape:10716
# mean of all impurity:0.396169191401
# pass node id shape:(47,)
# pass test data shape: 0
# not pass test data shape: 1422
# pass test data ('nor gini:', nan)
# train==1 (5345,)
# train==0 (12485,)
#
# layer: 62
# train==1 (5345,)
# train==0 (5345,)
# X_train.shape, y_train.shape:(9086, 14)(9086,)
# X_valid.shape, y_valid.shape:(1604, 14)(1604,)
# all data ('nor gini:', 0.56151510245799419)
# train data ('nor gini:', 0.5516834296331159)
# valid data ('nor gini:', 0.51206149215489938)
# mean of all impurity:0.0792295608223
# pass node id shape:(1,)
# pass data shape:(143, 14) (7,)
# not pass data shape:(10547, 14) (39769,)
# all data shape:10690
# mean of all impurity:0.389467940928
# pass node id shape:(47,)
# pass test data shape: 0
# not pass test data shape: 1422
# pass test data ('nor gini:', nan)
# train==1 (5338,)
# train==0 (12349,)
#
# layer: 63
# train==1 (5338,)
# train==0 (5338,)
# X_train.shape, y_train.shape:(9074, 14)(9074,)
# X_valid.shape, y_valid.shape:(1602, 14)(1602,)
# all data ('nor gini:', 0.5553891515774203)
# train data ('nor gini:', 0.54191872483436354)
# valid data ('nor gini:', 0.50688667879258276)
# mean of all impurity:0.1171875
# pass node id shape:(1,)
# pass data shape:(225, 14) (17,)
# not pass data shape:(10451, 14) (39492,)
# all data shape:10676
# mean of all impurity:0.396039540668
# pass node id shape:(49,)
# pass test data shape: 72
# not pass test data shape: 1350
# pass test data ('nor gini:', 0.041871921182266042)
# train==1 (5321,)
# train==0 (12141,)
#
# layer: 64
# train==1 (5321,)
# train==0 (5321,)
# X_train.shape, y_train.shape:(9045, 14)(9045,)
# X_valid.shape, y_valid.shape:(1597, 14)(1597,)
# all data ('nor gini:', 0.55635263622865505)
# train data ('nor gini:', 0.54829446585993291)
# valid data ('nor gini:', 0.48945580471830391)
# mean of all impurity:0.101893491124
# pass node id shape:(1,)
# pass data shape:(145, 14) (9,)
# not pass data shape:(10497, 14) (39580,)
# all data shape:10642
# mean of all impurity:0.394667402385
# pass node id shape:(47,)
# pass test data shape: 6
# not pass test data shape: 1344
# pass test data ('nor gini:', nan)
# train==1 (5312,)
# train==0 (12005,)
#
# layer: 65
# train==1 (5312,)
# train==0 (5312,)
# X_train.shape, y_train.shape:(9030, 14)(9030,)
# X_valid.shape, y_valid.shape:(1594, 14)(1594,)
# all data ('nor gini:', 0.56456270299571787)
# train data ('nor gini:', 0.55513230783569978)
# valid data ('nor gini:', 0.51840417878210165)
# mean of all impurity:0.0873168439489
# pass node id shape:(1,)
# pass data shape:(177, 14) (9,)
# not pass data shape:(10447, 14) (39401,)
# all data shape:10624
# mean of all impurity:0.397512531716
# pass node id shape:(47,)
# pass test data shape: 92
# not pass test data shape: 1252
# pass test data ('nor gini:', -0.20270270270270271)
# train==1 (5303,)
# train==0 (11837,)
#
# layer: 66
# train==1 (5303,)
# train==0 (5303,)
# X_train.shape, y_train.shape:(9015, 14)(9015,)
# X_valid.shape, y_valid.shape:(1591, 14)(1591,)
# all data ('nor gini:', 0.55282670471163509)
# train data ('nor gini:', 0.54951953866892256)
# valid data ('nor gini:', 0.4830062260990487)
# mean of all impurity:0.0693545882718
# pass node id shape:(1,)
# pass data shape:(170, 14) (156,)
# not pass data shape:(10436, 14) (39263,)
# all data shape:10606
# mean of all impurity:0.39312624653
# pass node id shape:(52,)
# pass test data shape: 114
# not pass test data shape: 1138
# pass test data ('nor gini:', 0.14031620553359681)
# train==1 (5147,)
# train==0 (11823,)
#
# layer: 67
# train==1 (5147,)
# train==0 (5147,)
# X_train.shape, y_train.shape:(8749, 14)(8749,)
# X_valid.shape, y_valid.shape:(1545, 14)(1545,)
# all data ('nor gini:', 0.54809169952644254)
# train data ('nor gini:', 0.5379892089620486)
# valid data ('nor gini:', 0.52027629382863338)
# mean of all impurity:0.0915310650888
# pass node id shape:(1,)
# pass data shape:(118, 14) (7,)
# not pass data shape:(10176, 14) (38422,)
# all data shape:10294
# mean of all impurity:0.39547709184
# pass node id shape:(57,)
# pass test data shape: 12
# not pass test data shape: 1126
# pass test data ('nor gini:', 0.0)
# train==1 (5140,)
# train==0 (11712,)
#
# layer: 68
# train==1 (5140,)
# train==0 (5140,)
# X_train.shape, y_train.shape:(8738, 14)(8738,)
# X_valid.shape, y_valid.shape:(1542, 14)(1542,)
# all data ('nor gini:', 0.52371860285545579)
# train data ('nor gini:', 0.51743816494422901)
# valid data ('nor gini:', 0.45667946861000497)
# mean of all impurity:0.171772603762
# pass node id shape:(1,)
# pass data shape:(159, 14) (138,)
# not pass data shape:(10121, 14) (38035,)
# all data shape:10280
# mean of all impurity:0.413966112717
# pass node id shape:(47,)
# pass test data shape: 71
# not pass test data shape: 1055
# pass test data ('nor gini:', 0.12954545454545455)
# train==1 (5002,)
# train==0 (11691,)
#
# layer: 69
# train==1 (5002,)
# train==0 (5002,)
# X_train.shape, y_train.shape:(8503, 14)(8503,)
# X_valid.shape, y_valid.shape:(1501, 14)(1501,)
# all data ('nor gini:', 0.53362509454434925)
# train data ('nor gini:', 0.51609095131841032)
# valid data ('nor gini:', 0.48557123834886817)
# mean of all impurity:0.109861111111
# pass node id shape:(1,)
# pass data shape:(142, 14) (8,)
# not pass data shape:(9862, 14) (37237,)
# all data shape:10004
# mean of all impurity:0.411604598455
# pass node id shape:(40,)
# pass test data shape: 45
# not pass test data shape: 1010
# pass test data ('nor gini:', 0.19548872180451135)
# train==1 (4994,)
# train==0 (11557,)
#
# layer: 70
# train==1 (4994,)
# train==0 (4994,)
# X_train.shape, y_train.shape:(8489, 14)(8489,)
# X_valid.shape, y_valid.shape:(1499, 14)(1499,)
# all data ('nor gini:', 0.54427162815643082)
# train data ('nor gini:', 0.53146585937439272)
# valid data ('nor gini:', 0.51063996439697379)
# mean of all impurity:0.153553259886
# pass node id shape:(1,)
# pass data shape:(200, 14) (17,)
# not pass data shape:(9788, 14) (36782,)
# all data shape:9988
# mean of all impurity:0.414921372591
# pass node id shape:(44,)
# pass test data shape: 12
# not pass test data shape: 998
# pass test data ('nor gini:', -0.1111111111111111)
# train==1 (4977,)
# train==0 (11374,)
#
# layer: 71
# train==1 (4977,)
# train==0 (4977,)
# X_train.shape, y_train.shape:(8460, 14)(8460,)
# X_valid.shape, y_valid.shape:(1494, 14)(1494,)
# all data ('nor gini:', 0.54029790805032873)
# train data ('nor gini:', 0.51755802580911969)
# valid data ('nor gini:', 0.51297918133936915)
# mean of all impurity:0.0997229916898
# pass node id shape:(1,)
# pass data shape:(140, 14) (8,)
# not pass data shape:(9814, 14) (36844,)
# all data shape:9954
# mean of all impurity:0.414901793668
# pass node id shape:(40,)
# pass test data shape: 2
# not pass test data shape: 996
# pass test data ('nor gini:', nan)
# train==1 (4969,)
# train==0 (11242,)
#
# layer: 72
# train==1 (4969,)
# train==0 (4969,)
# X_train.shape, y_train.shape:(8447, 14)(8447,)
# X_valid.shape, y_valid.shape:(1491, 14)(1491,)
# all data ('nor gini:', 0.51516079102793932)
# train data ('nor gini:', 0.50425340308125077)
# valid data ('nor gini:', 0.47876279756014173)
# mean of all impurity:0.152777777778
# pass node id shape:(1,)
# pass data shape:(140, 14) (12,)
# not pass data shape:(9798, 14) (37015,)
# all data shape:9938
# mean of all impurity:0.418643339528
# pass node id shape:(47,)
# pass test data shape: 13
# not pass test data shape: 983
# pass test data ('nor gini:', 0.090909090909090912)
# train==1 (4957,)
# train==0 (11114,)
#
# layer: 73
# train==1 (4957,)
# train==0 (4957,)
# X_train.shape, y_train.shape:(8426, 14)(8426,)
# X_valid.shape, y_valid.shape:(1488, 14)(1488,)
# all data ('nor gini:', 0.52495207015149714)
# train data ('nor gini:', 0.51639339967522224)
# valid data ('nor gini:', 0.4476059371025552)
# mean of all impurity:0.0932333717801
# pass node id shape:(1,)
# pass data shape:(119, 14) (8,)
# not pass data shape:(9795, 14) (36864,)
# all data shape:9914
# mean of all impurity:0.419362759347
# pass node id shape:(41,)
# pass test data shape: 36
# not pass test data shape: 947
# pass test data ('nor gini:', -0.02307692307692313)
# train==1 (4949,)
# train==0 (11003,)
#
# layer: 74
# train==1 (4949,)
# train==0 (4949,)
# X_train.shape, y_train.shape:(8413, 14)(8413,)
# X_valid.shape, y_valid.shape:(1485, 14)(1485,)
# all data ('nor gini:', 0.52121001767023434)
# train data ('nor gini:', 0.51054279594919183)
# valid data ('nor gini:', 0.46509198158554421)
# mean of all impurity:0.132653061224
# pass node id shape:(1,)
# pass data shape:(129, 14) (9,)
# not pass data shape:(9769, 14) (36833,)
# all data shape:9898
# mean of all impurity:0.416662654371
# pass node id shape:(42,)
# pass test data shape: 3
# not pass test data shape: 944
# pass test data ('nor gini:', nan)
# train==1 (4940,)
# train==0 (10883,)
#
# layer: 75
# train==1 (4940,)
# train==0 (4940,)
# X_train.shape, y_train.shape:(8398, 14)(8398,)
# X_valid.shape, y_valid.shape:(1482, 14)(1482,)
# all data ('nor gini:', 0.52625333967119625)
# train data ('nor gini:', 0.51618279020719682)
# valid data ('nor gini:', 0.45323549713066008)
# mean of all impurity:0.1638
# pass node id shape:(1,)
# pass data shape:(114, 14) (11,)
# not pass data shape:(9766, 14) (36754,)
# all data shape:9880
# mean of all impurity:0.411885389403
# pass node id shape:(42,)
# pass test data shape: 11
# not pass test data shape: 933
# pass test data ('nor gini:', 0.0)
# train==1 (4929,)
# train==0 (10780,)
#
# layer: 76
# train==1 (4929,)
# train==0 (4929,)
# X_train.shape, y_train.shape:(8379, 14)(8379,)
# X_valid.shape, y_valid.shape:(1479, 14)(1479,)
# all data ('nor gini:', 0.51466062559845038)
# train data ('nor gini:', 0.49552772319365795)
# valid data ('nor gini:', 0.48193321873971401)
# mean of all impurity:0.143020251187
# pass node id shape:(1,)
# pass data shape:(156, 14) (12,)
# not pass data shape:(9702, 14) (36652,)
# all data shape:9858
# mean of all impurity:0.413763058085
# pass node id shape:(42,)
# pass test data shape: 22
# not pass test data shape: 911
# pass test data ('nor gini:', 0.47222222222222215)
# train==1 (4917,)
# train==0 (10636,)
#
# layer: 77
# train==1 (4917,)
# train==0 (4917,)
# X_train.shape, y_train.shape:(8358, 14)(8358,)
# X_valid.shape, y_valid.shape:(1476, 14)(1476,)
# all data ('nor gini:', 0.51155312000646569)
# train data ('nor gini:', 0.48731785501419755)
# valid data ('nor gini:', 0.47583008350408718)
# mean of all impurity:0.174817898023
# pass node id shape:(1,)
# pass data shape:(143, 14) (16,)
# not pass data shape:(9691, 14) (36711,)
# all data shape:9834
# mean of all impurity:0.416999795354
# pass node id shape:(37,)
# pass test data shape: 14
# not pass test data shape: 897
# pass test data ('nor gini:', -0.75000000000000011)
# train==1 (4901,)
# train==0 (10509,)
#
# layer: 78
# train==1 (4901,)
# train==0 (4901,)
# X_train.shape, y_train.shape:(8331, 14)(8331,)
# X_valid.shape, y_valid.shape:(1471, 14)(1471,)
# all data ('nor gini:', 0.51141168904771517)
# train data ('nor gini:', 0.50450943699611384)
# valid data ('nor gini:', 0.45929458740017742)
# mean of all impurity:0.122755607651
# pass node id shape:(1,)
# pass data shape:(170, 14) (16,)
# not pass data shape:(9632, 14) (36547,)
# all data shape:9802
# mean of all impurity:0.412367111865
# pass node id shape:(50,)
# pass test data shape: 22
# not pass test data shape: 875
# pass test data ('nor gini:', 0.4583333333333332)
# train==1 (4885,)
# train==0 (10355,)
#
# layer: 79
# train==1 (4885,)
# train==0 (4885,)
# X_train.shape, y_train.shape:(8304, 14)(8304,)
# X_valid.shape, y_valid.shape:(1466, 14)(1466,)
# all data ('nor gini:', 0.51348294289644425)
# train data ('nor gini:', 0.49880098176796178)
# valid data ('nor gini:', 0.44576940901451539)
# mean of all impurity:0.151819262782
# pass node id shape:(1,)
# pass data shape:(183, 14) (18,)
# not pass data shape:(9587, 14) (36439,)
# all data shape:9770
# mean of all impurity:0.41268166568
# pass node id shape:(42,)
# pass test data shape: 24
# not pass test data shape: 851
# pass test data ('nor gini:', 0.0625)
# train==1 (4867,)
# train==0 (10190,)
#
# layer: 80
# train==1 (4867,)
# train==0 (4867,)
# X_train.shape, y_train.shape:(8273, 14)(8273,)
# X_valid.shape, y_valid.shape:(1461, 14)(1461,)
# all data ('nor gini:', 0.49945779852141753)
# train data ('nor gini:', 0.4906809988082263)
# valid data ('nor gini:', 0.42504731742967961)
# mean of all impurity:0.151628987091
# pass node id shape:(1,)
# pass data shape:(141, 14) (14,)
# not pass data shape:(9593, 14) (36457,)
# all data shape:9734
# mean of all impurity:0.41372099457
# pass node id shape:(44,)
# pass test data shape: 4
# not pass test data shape: 847
# pass test data ('nor gini:', nan)
# train==1 (4853,)
# train==0 (10063,)
#
# layer: 81
# train==1 (4853,)
# train==0 (4853,)
# X_train.shape, y_train.shape:(8250, 14)(8250,)
# X_valid.shape, y_valid.shape:(1456, 14)(1456,)
# all data ('nor gini:', 0.48839690740450054)
# train data ('nor gini:', 0.47942564554637296)
# valid data ('nor gini:', 0.40120456466610316)
# mean of all impurity:0.175738115749
# pass node id shape:(1,)
# pass data shape:(138, 14) (16,)
# not pass data shape:(9568, 14) (36302,)
# all data shape:9706
# mean of all impurity:0.429188672645
# pass node id shape:(39,)
# pass test data shape: 14
# not pass test data shape: 833
# pass test data ('nor gini:', 0.15555555555555539)
# train==1 (4837,)
# train==0 (9941,)
#
# layer: 82
# train==1 (4837,)
# train==0 (4837,)
# X_train.shape, y_train.shape:(8222, 14)(8222,)
# X_valid.shape, y_valid.shape:(1452, 14)(1452,)
# all data ('nor gini:', 0.5123321714393253)
# train data ('nor gini:', 0.49893117414752042)
# valid data ('nor gini:', 0.4346659684751345)
# mean of all impurity:0.198603448941
# pass node id shape:(1,)
# pass data shape:(188, 14) (24,)
# not pass data shape:(9486, 14) (36012,)
# all data shape:9674
# mean of all impurity:0.417838705138
# pass node id shape:(42,)
# pass test data shape: 10
# not pass test data shape: 823
# pass test data ('nor gini:', 0.25)
# train==1 (4813,)
# train==0 (9777,)
#
# layer: 83
# train==1 (4813,)
# train==0 (4813,)
# X_train.shape, y_train.shape:(8182, 14)(8182,)
# X_valid.shape, y_valid.shape:(1444, 14)(1444,)
# all data ('nor gini:', 0.49007054574517239)
# train data ('nor gini:', 0.4748186888114509)
# valid data ('nor gini:', 0.42346206674288883)
# mean of all impurity:0.0890907502839
# pass node id shape:(1,)
# pass data shape:(125, 14) (7,)
# not pass data shape:(9501, 14) (36062,)
# all data shape:9626
# mean of all impurity:0.422227787467
# pass node id shape:(45,)
# pass test data shape: 36
# not pass test data shape: 787
# pass test data ('nor gini:', -0.23152709359605914)
# train==1 (4806,)
# train==0 (9659,)
#
# layer: 84
# train==1 (4806,)
# train==0 (4806,)
# X_train.shape, y_train.shape:(8170, 14)(8170,)
# X_valid.shape, y_valid.shape:(1442, 14)(1442,)
# all data ('nor gini:', 0.48427146397146459)
# train data ('nor gini:', 0.47424224219425348)
# valid data ('nor gini:', 0.42379689174189816)
# mean of all impurity:0.177571166208
# pass node id shape:(1,)
# pass data shape:(150, 14) (15,)
# not pass data shape:(9462, 14) (35957,)
# all data shape:9612
# mean of all impurity:0.427431129901
# pass node id shape:(41,)
# pass test data shape: 11
# not pass test data shape: 776
# pass test data ('nor gini:', 1.0)
# train==1 (4791,)
# train==0 (9524,)
#
# layer: 85
# train==1 (4791,)
# train==0 (4791,)
# X_train.shape, y_train.shape:(8144, 14)(8144,)
# X_valid.shape, y_valid.shape:(1438, 14)(1438,)
# all data ('nor gini:', 0.50196946624813699)
# train data ('nor gini:', 0.48313715112262201)
# valid data ('nor gini:', 0.4251906816955246)
# mean of all impurity:0.127835447905
# pass node id shape:(1,)
# pass data shape:(117, 14) (7,)
# not pass data shape:(9465, 14) (35931,)
# all data shape:9582
# mean of all impurity:0.411735721428
# pass node id shape:(38,)
# pass test data shape: 1
# not pass test data shape: 775
# pass test data ('nor gini:', nan)
# train==1 (4784,)
# train==0 (9414,)
#
# layer: 86
# train==1 (4784,)
# train==0 (4784,)
# X_train.shape, y_train.shape:(8132, 14)(8132,)
# X_valid.shape, y_valid.shape:(1436, 14)(1436,)
# all data ('nor gini:', 0.47395215797362433)
# train data ('nor gini:', 0.46440579914925639)
# valid data ('nor gini:', 0.40533515413443394)
# mean of all impurity:0.171670630202
# pass node id shape:(1,)
# pass data shape:(136, 14) (13,)
# not pass data shape:(9432, 14) (35829,)
# all data shape:9568
# mean of all impurity:0.433069355198
# pass node id shape:(40,)
# pass test data shape: 16
# not pass test data shape: 759
# pass test data ('nor gini:', 0.39682539682539697)
# train==1 (4771,)
# train==0 (9291,)
#
# layer: 87
# train==1 (4771,)
# train==0 (4771,)
# X_train.shape, y_train.shape:(8110, 14)(8110,)
# X_valid.shape, y_valid.shape:(1432, 14)(1432,)
# all data ('nor gini:', 0.47767227600941409)
# train data ('nor gini:', 0.47588488127944822)
# valid data ('nor gini:', 0.38560360163540452)
# mean of all impurity:0.0941084207431
# pass node id shape:(1,)
# pass data shape:(116, 14) (8,)
# not pass data shape:(9426, 14) (35883,)
# all data shape:9542
# mean of all impurity:0.422724563731
# pass node id shape:(45,)
# pass test data shape: 54
# not pass test data shape: 705
# pass test data ('nor gini:', 0.14871794871794863)
# train==1 (4763,)
# train==0 (9183,)
#
# layer: 88
# train==1 (4763,)
# train==0 (4763,)
# X_train.shape, y_train.shape:(8097, 14)(8097,)
# X_valid.shape, y_valid.shape:(1429, 14)(1429,)
# all data ('nor gini:', 0.47805519742006675)
# train data ('nor gini:', 0.46403420744106039)
# valid data ('nor gini:', 0.44124502948032363)
# mean of all impurity:0.172335600907
# pass node id shape:(1,)
# pass data shape:(125, 14) (12,)
# not pass data shape:(9401, 14) (35839,)
# all data shape:9526
# mean of all impurity:0.431108219314
# pass node id shape:(39,)
# pass test data shape: 0
# not pass test data shape: 705
# pass test data ('nor gini:', nan)
# train==1 (4751,)
# train==0 (9070,)
#
# layer: 89
# train==1 (4751,)
# train==0 (4751,)
# X_train.shape, y_train.shape:(8076, 14)(8076,)
# X_valid.shape, y_valid.shape:(1426, 14)(1426,)
# all data ('nor gini:', 0.45922596760473278)
# train data ('nor gini:', 0.46097965808229441)
# valid data ('nor gini:', 0.33789039064144349)
# mean of all impurity:0.105628637097
# pass node id shape:(1,)
# pass data shape:(170, 14) (10,)
# not pass data shape:(9332, 14) (35589,)
# all data shape:9502
# mean of all impurity:0.436164836052
# pass node id shape:(36,)
# pass test data shape: 82
# not pass test data shape: 623
# pass test data ('nor gini:', 0.034722222222222321)
# train==1 (4741,)
# train==0 (8910,)
#
# layer: 90
# train==1 (4741,)
# train==0 (4741,)
# X_train.shape, y_train.shape:(8059, 14)(8059,)
# X_valid.shape, y_valid.shape:(1423, 14)(1423,)
# all data ('nor gini:', 0.46421521548994721)
# train data ('nor gini:', 0.4405774019253712)
# valid data ('nor gini:', 0.46066625578785997)
# mean of all impurity:0.2262
# pass node id shape:(1,)
# pass data shape:(113, 14) (17,)
# not pass data shape:(9369, 14) (35683,)
# all data shape:9482
# mean of all impurity:0.436420525029
# pass node id shape:(38,)
# pass test data shape: 0
# not pass test data shape: 623
# pass test data ('nor gini:', nan)
# train==1 (4724,)
# train==0 (8814,)
#
# layer: 91
# train==1 (4724,)
# train==0 (4724,)
# X_train.shape, y_train.shape:(8030, 14)(8030,)
# X_valid.shape, y_valid.shape:(1418, 14)(1418,)
# all data ('nor gini:', 0.46201831353185252)
# train data ('nor gini:', 0.45480525240807762)
# valid data ('nor gini:', 0.38346187741330984)
# mean of all impurity:0.158099112426
# pass node id shape:(1,)
# pass data shape:(128, 14) (10,)
# not pass data shape:(9320, 14) (35362,)
# all data shape:9448
# mean of all impurity:0.428679285543
# pass node id shape:(39,)
# pass test data shape: 62
# not pass test data shape: 561
# pass test data ('nor gini:', 0.043478260869565216)
# train==1 (4714,)
# train==0 (8696,)
#
# layer: 92
# train==1 (4714,)
# train==0 (4714,)
# X_train.shape, y_train.shape:(8013, 14)(8013,)
# X_valid.shape, y_valid.shape:(1415, 14)(1415,)
# all data ('nor gini:', 0.46266053382903899)
# train data ('nor gini:', 0.45700029940116016)
# valid data ('nor gini:', 0.39448533231047089)
# mean of all impurity:0.182867797339
# pass node id shape:(1,)
# pass data shape:(191, 14) (23,)
# not pass data shape:(9237, 14) (35108,)
# all data shape:9428
# mean of all impurity:0.432399063259
# pass node id shape:(43,)
# pass test data shape: 1
# not pass test data shape: 560
# pass test data ('nor gini:', nan)
# train==1 (4691,)
# train==0 (8528,)
#
# layer: 93
# train==1 (4691,)
# train==0 (4691,)
# X_train.shape, y_train.shape:(7974, 14)(7974,)
# X_valid.shape, y_valid.shape:(1408, 14)(1408,)
# all data ('nor gini:', 0.45303635944154086)
# train data ('nor gini:', 0.44276536063500593)
# valid data ('nor gini:', 0.39041516012396699)
# mean of all impurity:0.175322839099
# pass node id shape:(1,)
# pass data shape:(122, 14) (12,)
# not pass data shape:(9260, 14) (35288,)
# all data shape:9382
# mean of all impurity:0.439561651492
# pass node id shape:(38,)
# pass test data shape: 24
# not pass test data shape: 536
# pass test data ('nor gini:', -0.022222222222222143)
# train==1 (4679,)
# train==0 (8418,)
#
# layer: 94
# train==1 (4679,)
# train==0 (4679,)
# X_train.shape, y_train.shape:(7954, 14)(7954,)
# X_valid.shape, y_valid.shape:(1404, 14)(1404,)
# all data ('nor gini:', 0.4468058594509553)
# train data ('nor gini:', 0.4354507237333804)
# valid data ('nor gini:', 0.36108067304648511)
# mean of all impurity:0.211762688615
# pass node id shape:(1,)
# pass data shape:(127, 14) (110,)
# not pass data shape:(9231, 14) (35037,)
# all data shape:9358
# mean of all impurity:0.426621891537
# pass node id shape:(44,)
# pass test data shape: 9
# not pass test data shape: 527
# pass test data ('nor gini:', -0.22222222222222235)
# train==1 (4569,)
# train==0 (8401,)
#
# layer: 95
# train==1 (4569,)
# train==0 (4569,)
# X_train.shape, y_train.shape:(7767, 14)(7767,)
# X_valid.shape, y_valid.shape:(1371, 14)(1371,)
# all data ('nor gini:', 0.44026203404033992)
# train data ('nor gini:', 0.42824912416291866)
# valid data ('nor gini:', 0.395152263199336)
# mean of all impurity:0.186368
# pass node id shape:(1,)
# pass data shape:(149, 14) (18,)
# not pass data shape:(8989, 14) (34300,)
# all data shape:9138
# mean of all impurity:0.440921488301
# pass node id shape:(40,)
# pass test data shape: 89
# not pass test data shape: 438
# pass test data ('nor gini:', -0.01990632318501161)
# train==1 (4551,)
# train==0 (8270,)
#
# layer: 96
# train==1 (4551,)
# train==0 (4551,)
# X_train.shape, y_train.shape:(7736, 14)(7736,)
# X_valid.shape, y_valid.shape:(1366, 14)(1366,)
# all data ('nor gini:', 0.43942257288560171)
# train data ('nor gini:', 0.42674373776186031)
# valid data ('nor gini:', 0.36541268925955395)
# mean of all impurity:0.186009255963
# pass node id shape:(1,)
# pass data shape:(123, 14) (16,)
# not pass data shape:(8979, 14) (34312,)
# all data shape:9102
# mean of all impurity:0.434856246148
# pass node id shape:(35,)
# pass test data shape: 2
# not pass test data shape: 436
# pass test data ('nor gini:', nan)
# train==1 (4535,)
# train==0 (8163,)
#
# layer: 97
# train==1 (4535,)
# train==0 (4535,)
# X_train.shape, y_train.shape:(7709, 14)(7709,)
# X_valid.shape, y_valid.shape:(1361, 14)(1361,)
# all data ('nor gini:', 0.42245258913582839)
# train data ('nor gini:', 0.42307330400069459)
# valid data ('nor gini:', 0.31504275719098207)
# mean of all impurity:0.205862946555
# pass node id shape:(1,)
# pass data shape:(121, 14) (16,)
# not pass data shape:(8949, 14) (34153,)
# all data shape:9070
# mean of all impurity:0.442489183495
# pass node id shape:(41,)
# pass test data shape: 12
# not pass test data shape: 424
# pass test data ('nor gini:', -0.88571428571428579)
# train==1 (4519,)
# train==0 (8058,)
#
# layer: 98
# train==1 (4519,)
# train==0 (4519,)
# X_train.shape, y_train.shape:(7682, 14)(7682,)
# X_valid.shape, y_valid.shape:(1356, 14)(1356,)
# all data ('nor gini:', 0.43321074437692964)
# train data ('nor gini:', 0.4175980244665578)
# valid data ('nor gini:', 0.34634662072206118)
# mean of all impurity:0.20317119054
# pass node id shape:(1,)
# pass data shape:(141, 14) (123,)
# not pass data shape:(8897, 14) (33910,)
# all data shape:9038
# mean of all impurity:0.433634012304
# pass node id shape:(35,)
# pass test data shape: 0
# not pass test data shape: 424
# pass test data ('nor gini:', nan)
# train==1 (4396,)
# train==0 (8040,)
#
# layer: 99
# train==1 (4396,)
# train==0 (4396,)
# X_train.shape, y_train.shape:(7473, 14)(7473,)
# X_valid.shape, y_valid.shape:(1319, 14)(1319,)
# all data ('nor gini:', 0.43075194092404306)
# train data ('nor gini:', 0.42336459469200571)
# valid data ('nor gini:', 0.35082080286936124)
# mean of all impurity:0.247847090947
# pass node id shape:(1,)
# pass data shape:(170, 14) (23,)
# not pass data shape:(8622, 14) (33027,)
# all data shape:8792
# mean of all impurity:0.450538943194
# pass node id shape:(39,)
# pass test data shape: 13
# not pass test data shape: 411
# pass test data ('nor gini:', 0.27777777777777779)
# train==1 (4373,)
# train==0 (7893,)
#
# layer: 100
# train==1 (4373,)
# train==0 (4373,)
# X_train.shape, y_train.shape:(7434, 14)(7434,)
# X_valid.shape, y_valid.shape:(1312, 14)(1312,)
# all data ('nor gini:', 0.40910203555077185)
# train data ('nor gini:', 0.41469311611990917)
# valid data ('nor gini:', 0.25217039708506833)
# mean of all impurity:0.215857988166
# pass node id shape:(1,)
# pass data shape:(150, 14) (21,)
# not pass data shape:(8596, 14) (32950,)
# all data shape:8746
# mean of all impurity:0.436051570699
# pass node id shape:(39,)
# pass test data shape: 20
# not pass test data shape: 391
# pass test data ('nor gini:', 0.64583333333333337)
# train==1 (4352,)
# train==0 (7764,)
#
# layer: 101
# train==1 (4352,)
# train==0 (4352,)
# X_train.shape, y_train.shape:(7398, 14)(7398,)
# X_valid.shape, y_valid.shape:(1306, 14)(1306,)
# all data ('nor gini:', 0.41850317720723412)
# train data ('nor gini:', 0.41201457237552985)
# valid data ('nor gini:', 0.33330675478238037)
# mean of all impurity:0.2262
# pass node id shape:(1,)
# pass data shape:(111, 14) (15,)
# not pass data shape:(8593, 14) (32895,)
# all data shape:8704
# mean of all impurity:0.446903208171
# pass node id shape:(36,)
# pass test data shape: 2
# not pass test data shape: 389
# pass test data ('nor gini:', -1.0)
# train==1 (4337,)
# train==0 (7668,)
# 389

# %%
# 均衡数据进行layer

# %%
metrics.roc_auc_score(y_sub, test_y)
# Out:
# 0.89942379520673388

# %%
test_y_acc_index = np.where(test_y > 0.5)[0]
test_y_acc = np.array([0] * len(test_y))
test_y_acc[test_y_acc_index] = 1
metrics.accuracy_score(y_sub, test_y_acc)
# Out:
# 0.82101836496529701

# %%
# 不均衡数据进行layer

# %%
metrics.roc_auc_score(y_sub, test_y)
# Out:
# 0.90421133210426941

# %%
test_y_acc_index = np.where(test_y > 0.5)[0]
test_y_acc = np.array([0] * len(test_y))
test_y_acc[test_y_acc_index] = 1
metrics.accuracy_score(y_sub, test_y_acc)
# Out:
# 0.86002088323813031

# %%
X = X_train.copy()
y = y_train.copy()

X_test = X_sub.copy()
test_y = np.array(([0.0] * len(X_test)))
all_data_mask = np.array([False] * len(X_test))
real_y = y_sub.copy()

# 不均衡数据进行layer
X_train_np = X
y_train_np = y
maxlayer = 100
layer = 0

enhancedDTree = EnhancedDTree.EnhancedDTree()
counter = 0
while 1:
    layer += 1
    print()
    print("layer:", layer)
    X = X_train_np
    y = y_train_np
    clf, data_mask, all_false_data_index, p_test  = \
        enhancedDTree.TrainModelLayer(X, y, X_test, all_data_mask, test_y, real_y, verbose=True, feval=gini_metrix)
    X_train_np = enhancedDTree.X_train_np
    y_train_np = enhancedDTree.y_train_np
    
    if X_train_np.shape[0] < 1000 or layer > maxlayer or y_train_np[y_train_np==1].shape[0] <= 10:
        all_data_mask = all_false_data_index[~data_mask]
        test_y[all_data_mask] = p_test[~data_mask]
        print(len(p_test[~data_mask]))
        break
        
    all_data_mask[~all_data_mask] = data_mask
# Out:
# layer: 1
# X_train.shape, y_train.shape:(27676, 14)(27676,)
# X_valid.shape, y_valid.shape:(4885, 14)(4885,)
# all data ('nor gini:', 0.82519443890693234)
# train data ('nor gini:', 0.82600761798654876)
# valid data ('nor gini:', 0.82013964928111982)
# mean of all impurity:0.0
# pass node id shape:(12,)
# pass data shape:(3317, 14) (1017,)
# not pass data shape:(29244, 14) (101832,)
# all data shape:32561
# mean of all impurity:0.211628767054
# pass node id shape:(142,)
# pass test data shape: 9784
# not pass test data shape: 6497
# pass test data ('nor gini:', 0.88842402645976137)
#
# layer: 2
# X_train.shape, y_train.shape:(24857, 14)(24857,)
# X_valid.shape, y_valid.shape:(4387, 14)(4387,)
# all data ('nor gini:', 0.77777832972360772)
# train data ('nor gini:', 0.78213332778434197)
# valid data ('nor gini:', 0.75273019346565562)
# mean of all impurity:0.0
# pass node id shape:(7,)
# pass data shape:(5951, 14) (3,)
# not pass data shape:(23293, 14) (83752,)
# all data shape:29244
# mean of all impurity:0.23799863411
# pass node id shape:(117,)
# pass test data shape: 416
# not pass test data shape: 6081
# pass test data ('nor gini:', 0.4479885057471264)
#
# layer: 3
# X_train.shape, y_train.shape:(19799, 14)(19799,)
# X_valid.shape, y_valid.shape:(3494, 14)(3494,)
# all data ('nor gini:', 0.69965307977057667)
# train data ('nor gini:', 0.70262339463802648)
# valid data ('nor gini:', 0.68279629231836114)
# mean of all impurity:0.0
# pass node id shape:(3,)
# pass data shape:(658, 14) (5,)
# not pass data shape:(22635, 14) (81853,)
# all data shape:23293
# mean of all impurity:0.265173056323
# pass node id shape:(101,)
# pass test data shape: 485
# not pass test data shape: 5596
# pass test data ('nor gini:', 0.44393047378749639)
#
# layer: 4
# X_train.shape, y_train.shape:(19239, 14)(19239,)
# X_valid.shape, y_valid.shape:(3396, 14)(3396,)
# all data ('nor gini:', 0.69038296566172419)
# train data ('nor gini:', 0.69000785927529662)
# valid data ('nor gini:', 0.69287425867500085)
# mean of all impurity:0.0
# pass node id shape:(2,)
# pass data shape:(310, 14) (0,)
# not pass data shape:(22325, 14) (80801,)
# all data shape:22635
# mean of all impurity:0.258346918678
# pass node id shape:(98,)
# pass test data shape: 25
# not pass test data shape: 5571
# pass test data ('nor gini:', 0.47619047619047605)
#
# layer: 5
# X_train.shape, y_train.shape:(18976, 14)(18976,)
# X_valid.shape, y_valid.shape:(3349, 14)(3349,)
# all data ('nor gini:', 0.68545123125539387)
# train data ('nor gini:', 0.68302200985674799)
# valid data ('nor gini:', 0.69685904514097652)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(190, 14) (0,)
# not pass data shape:(22135, 14) (80249,)
# all data shape:22325
# mean of all impurity:0.278249152925
# pass node id shape:(97,)
# pass test data shape: 347
# not pass test data shape: 5224
# pass test data ('nor gini:', 0.42804896253172098)
#
# layer: 6
# X_train.shape, y_train.shape:(18814, 14)(18814,)
# X_valid.shape, y_valid.shape:(3321, 14)(3321,)
# all data ('nor gini:', 0.67737677014061226)
# train data ('nor gini:', 0.67948406863188626)
# valid data ('nor gini:', 0.66618513952801828)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(191, 14) (1,)
# not pass data shape:(21944, 14) (79566,)
# all data shape:22135
# mean of all impurity:0.2750204518
# pass node id shape:(91,)
# pass test data shape: 225
# not pass test data shape: 4999
# pass test data ('nor gini:', 0.50819672131147564)
#
# layer: 7
# X_train.shape, y_train.shape:(18652, 14)(18652,)
# X_valid.shape, y_valid.shape:(3292, 14)(3292,)
# all data ('nor gini:', 0.67621641944816269)
# train data ('nor gini:', 0.67923731384071195)
# valid data ('nor gini:', 0.65318672034621594)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(126, 14) (1,)
# not pass data shape:(21818, 14) (79146,)
# all data shape:21944
# mean of all impurity:0.267122103301
# pass node id shape:(92,)
# pass test data shape: 131
# not pass test data shape: 4868
# pass test data ('nor gini:', 0.51655011655011651)
#
# layer: 8
# X_train.shape, y_train.shape:(18545, 14)(18545,)
# X_valid.shape, y_valid.shape:(3273, 14)(3273,)
# all data ('nor gini:', 0.67802207054539898)
# train data ('nor gini:', 0.68000111445990596)
# valid data ('nor gini:', 0.66484128384775287)
# mean of all impurity:0.00737997256516
# pass node id shape:(1,)
# pass data shape:(340, 14) (4,)
# not pass data shape:(21478, 14) (77930,)
# all data shape:21818
# mean of all impurity:0.284581236096
# pass node id shape:(94,)
# pass test data shape: 234
# not pass test data shape: 4634
# pass test data ('nor gini:', 0.56152666828048081)
#
# layer: 9
# X_train.shape, y_train.shape:(18256, 14)(18256,)
# X_valid.shape, y_valid.shape:(3222, 14)(3222,)
# all data ('nor gini:', 0.67172846120917307)
# train data ('nor gini:', 0.67193510895840836)
# valid data ('nor gini:', 0.6690980252624088)
# mean of all impurity:0.0160417317514
# pass node id shape:(1,)
# pass data shape:(442, 14) (5,)
# not pass data shape:(21036, 14) (76504,)
# all data shape:21478
# mean of all impurity:0.279842230782
# pass node id shape:(88,)
# pass test data shape: 53
# not pass test data shape: 4581
# pass test data ('nor gini:', -0.070175438596491169)
#
# layer: 10
# X_train.shape, y_train.shape:(17880, 14)(17880,)
# X_valid.shape, y_valid.shape:(3156, 14)(3156,)
# all data ('nor gini:', 0.66404532002684169)
# train data ('nor gini:', 0.66943617724867721)
# valid data ('nor gini:', 0.63349519573729185)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(135, 14) (1,)
# not pass data shape:(20901, 14) (76172,)
# all data shape:21036
# mean of all impurity:0.281071326549
# pass node id shape:(94,)
# pass test data shape: 147
# not pass test data shape: 4434
# pass test data ('nor gini:', 0.42039355992844368)
#
# layer: 11
# X_train.shape, y_train.shape:(17765, 14)(17765,)
# X_valid.shape, y_valid.shape:(3136, 14)(3136,)
# all data ('nor gini:', 0.65938131190391314)
# train data ('nor gini:', 0.6604086774579413)
# valid data ('nor gini:', 0.65296527068673704)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(244, 14) (2,)
# not pass data shape:(20657, 14) (75476,)
# all data shape:20901
# mean of all impurity:0.282875552397
# pass node id shape:(90,)
# pass test data shape: 24
# not pass test data shape: 4410
# pass test data ('nor gini:', 0.22689075630252101)
#
# layer: 12
# X_train.shape, y_train.shape:(17558, 14)(17558,)
# X_valid.shape, y_valid.shape:(3099, 14)(3099,)
# all data ('nor gini:', 0.65788719241193749)
# train data ('nor gini:', 0.65529477726978769)
# valid data ('nor gini:', 0.67047977440134288)
# mean of all impurity:0.0157470395566
# pass node id shape:(1,)
# pass data shape:(150, 14) (3,)
# not pass data shape:(20507, 14) (74848,)
# all data shape:20657
# mean of all impurity:0.287817247983
# pass node id shape:(90,)
# pass test data shape: 111
# not pass test data shape: 4299
# pass test data ('nor gini:', -0.041187739463601485)
#
# layer: 13
# X_train.shape, y_train.shape:(17430, 14)(17430,)
# X_valid.shape, y_valid.shape:(3077, 14)(3077,)
# all data ('nor gini:', 0.65274257834909633)
# train data ('nor gini:', 0.65457106771520202)
# valid data ('nor gini:', 0.64385884640681756)
# mean of all impurity:0.0236652443616
# pass node id shape:(1,)
# pass data shape:(200, 14) (198,)
# not pass data shape:(20307, 14) (74001,)
# all data shape:20507
# mean of all impurity:0.294788768405
# pass node id shape:(89,)
# pass test data shape: 78
# not pass test data shape: 4221
# pass test data ('nor gini:', -0.053254437869822563)
#
# layer: 14
# X_train.shape, y_train.shape:(17260, 14)(17260,)
# X_valid.shape, y_valid.shape:(3047, 14)(3047,)
# all data ('nor gini:', 0.64202685375507318)
# train data ('nor gini:', 0.64643077895122769)
# valid data ('nor gini:', 0.61784888260337945)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(130, 14) (129,)
# not pass data shape:(20177, 14) (73504,)
# all data shape:20307
# mean of all impurity:0.288489370385
# pass node id shape:(87,)
# pass test data shape: 11
# not pass test data shape: 4210
# pass test data ('nor gini:', 0.40000000000000002)
#
# layer: 15
# X_train.shape, y_train.shape:(17150, 14)(17150,)
# X_valid.shape, y_valid.shape:(3027, 14)(3027,)
# all data ('nor gini:', 0.62915366573332032)
# train data ('nor gini:', 0.63290421025378307)
# valid data ('nor gini:', 0.60660717219601923)
# mean of all impurity:0.0177763478051
# pass node id shape:(1,)
# pass data shape:(256, 14) (6,)
# not pass data shape:(19921, 14) (72740,)
# all data shape:20177
# mean of all impurity:0.311603525924
# pass node id shape:(98,)
# pass test data shape: 218
# not pass test data shape: 3992
# pass test data ('nor gini:', 0.23278029160382124)
#
# layer: 16
# X_train.shape, y_train.shape:(16932, 14)(16932,)
# X_valid.shape, y_valid.shape:(2989, 14)(2989,)
# all data ('nor gini:', 0.6275656226785209)
# train data ('nor gini:', 0.62935984350346952)
# valid data ('nor gini:', 0.61921641314726583)
# mean of all impurity:0.0162590701424
# pass node id shape:(1,)
# pass data shape:(147, 14) (4,)
# not pass data shape:(19774, 14) (72232,)
# all data shape:19921
# mean of all impurity:0.305021835406
# pass node id shape:(85,)
# pass test data shape: 16
# not pass test data shape: 3976
# pass test data ('nor gini:', 0.1794871794871794)
#
# layer: 17
# X_train.shape, y_train.shape:(16807, 14)(16807,)
# X_valid.shape, y_valid.shape:(2967, 14)(2967,)
# all data ('nor gini:', 0.62419727645941947)
# train data ('nor gini:', 0.63125323653993637)
# valid data ('nor gini:', 0.58443541601061377)
# mean of all impurity:0.0156240312481
# pass node id shape:(1,)
# pass data shape:(140, 14) (2,)
# not pass data shape:(19634, 14) (71636,)
# all data shape:19774
# mean of all impurity:0.319238765938
# pass node id shape:(86,)
# pass test data shape: 71
# not pass test data shape: 3905
# pass test data ('nor gini:', -0.36470588235294132)
#
# layer: 18
# X_train.shape, y_train.shape:(16688, 14)(16688,)
# X_valid.shape, y_valid.shape:(2946, 14)(2946,)
# all data ('nor gini:', 0.61991618729263609)
# train data ('nor gini:', 0.62632246289270821)
# valid data ('nor gini:', 0.58278510403176231)
# mean of all impurity:0.0
# pass node id shape:(1,)
# pass data shape:(117, 14) (1,)
# not pass data shape:(19517, 14) (71311,)
# all data shape:19634
# mean of all impurity:0.317969035931
# pass node id shape:(96,)
# pass test data shape: 69
# not pass test data shape: 3836
# pass test data ('nor gini:', 0.31040564373897706)
#
# layer: 19
# X_train.shape, y_train.shape:(16589, 14)(16589,)
# X_valid.shape, y_valid.shape:(2928, 14)(2928,)
# all data ('nor gini:', 0.61812337448288568)
# train data ('nor gini:', 0.62198557082958117)
# valid data ('nor gini:', 0.59397894188975131)
# mean of all impurity:0.031737773153
# pass node id shape:(1,)
# pass data shape:(152, 14) (5,)
# not pass data shape:(19365, 14) (70864,)
# all data shape:19517
# mean of all impurity:0.323038407078
# pass node id shape:(86,)
# pass test data shape: 15
# not pass test data shape: 3821
# pass test data ('nor gini:', 0.0)
#
# layer: 20
# X_train.shape, y_train.shape:(16460, 14)(16460,)
# X_valid.shape, y_valid.shape:(2905, 14)(2905,)
# all data ('nor gini:', 0.61857372240940989)
# train data ('nor gini:', 0.62802503860083303)
# valid data ('nor gini:', 0.56485597989563818)
# mean of all impurity:0.0161279661577
# pass node id shape:(1,)
# pass data shape:(148, 14) (4,)
# not pass data shape:(19217, 14) (70328,)
# all data shape:19365
# mean of all impurity:0.315801910109
# pass node id shape:(89,)
# pass test data shape: 13
# not pass test data shape: 3808
# pass test data ('nor gini:', 0.3333333333333332)
#
# layer: 21
# X_train.shape, y_train.shape:(16334, 14)(16334,)
# X_valid.shape, y_valid.shape:(2883, 14)(2883,)
# all data ('nor gini:', 0.61758244213673463)
# train data ('nor gini:', 0.62142654854213775)
# valid data ('nor gini:', 0.59467017672571909)
# mean of all impurity:0.0176977040816
# pass node id shape:(1,)
# pass data shape:(133, 14) (132,)
# not pass data shape:(19084, 14) (69828,)
# all data shape:19217
# mean of all impurity:0.322547591895
# pass node id shape:(95,)
# pass test data shape: 47
# not pass test data shape: 3761
# pass test data ('nor gini:', 0.28727272727272724)
#
# layer: 22
# X_train.shape, y_train.shape:(16221, 14)(16221,)
# X_valid.shape, y_valid.shape:(2863, 14)(2863,)
# all data ('nor gini:', 0.59939678327061474)
# train data ('nor gini:', 0.61077596363266284)
# valid data ('nor gini:', 0.53241784270306602)
# mean of all impurity:0.0393929446226
# pass node id shape:(1,)
# pass data shape:(232, 14) (7,)
# not pass data shape:(18852, 14) (69115,)
# all data shape:19084
# mean of all impurity:0.323752004068
# pass node id shape:(101,)
# pass test data shape: 94
# not pass test data shape: 3667
# pass test data ('nor gini:', 0.098684210526315805)
#
# layer: 23
# X_train.shape, y_train.shape:(16024, 14)(16024,)
# X_valid.shape, y_valid.shape:(2828, 14)(2828,)
# all data ('nor gini:', 0.60550740426100536)
# train data ('nor gini:', 0.61234258548057874)
# valid data ('nor gini:', 0.56497560499116672)
# mean of all impurity:0.0159989594173
# pass node id shape:(1,)
# pass data shape:(147, 14) (4,)
# not pass data shape:(18705, 14) (68501,)
# all data shape:18852
# mean of all impurity:0.324368011064
# pass node id shape:(85,)
# pass test data shape: 54
# not pass test data shape: 3613
# pass test data ('nor gini:', -0.12362637362637356)
#
# layer: 24
# X_train.shape, y_train.shape:(15899, 14)(15899,)
# X_valid.shape, y_valid.shape:(2806, 14)(2806,)
# all data ('nor gini:', 0.5982999042921171)
# train data ('nor gini:', 0.6047670577544767)
# valid data ('nor gini:', 0.56170860897042441)
# mean of all impurity:0.0185169010394
# pass node id shape:(1,)
# pass data shape:(121, 14) (2,)
# not pass data shape:(18584, 14) (68178,)
# all data shape:18705
# mean of all impurity:0.327960138658
# pass node id shape:(93,)
# pass test data shape: 68
# not pass test data shape: 3545
# pass test data ('nor gini:', 0.12996777658431785)
#
# layer: 25
# X_train.shape, y_train.shape:(15796, 14)(15796,)
# X_valid.shape, y_valid.shape:(2788, 14)(2788,)
# all data ('nor gini:', 0.59441481458805467)
# train data ('nor gini:', 0.60092725646300882)
# valid data ('nor gini:', 0.55620556753046724)
# mean of all impurity:0.0341776937618
# pass node id shape:(1,)
# pass data shape:(135, 14) (3,)
# not pass data shape:(18449, 14) (67791,)
# all data shape:18584
# mean of all impurity:0.339641278552
# pass node id shape:(80,)
# pass test data shape: 12
# not pass test data shape: 3533
# pass test data ('nor gini:', 0.43750000000000006)
#
# layer: 26
# X_train.shape, y_train.shape:(15681, 14)(15681,)
# X_valid.shape, y_valid.shape:(2768, 14)(2768,)
# all data ('nor gini:', 0.5902706653606512)
# train data ('nor gini:', 0.59331755294236777)
# valid data ('nor gini:', 0.57092315439901786)
# mean of all impurity:0.0268406682401
# pass node id shape:(1,)
# pass data shape:(177, 14) (4,)
# not pass data shape:(18272, 14) (67052,)
# all data shape:18449
# mean of all impurity:0.343640271533
# pass node id shape:(81,)
# pass test data shape: 65
# not pass test data shape: 3468
# pass test data ('nor gini:', 0.2039999999999999)
#
# layer: 27
# X_train.shape, y_train.shape:(15531, 14)(15531,)
# X_valid.shape, y_valid.shape:(2741, 14)(2741,)
# all data ('nor gini:', 0.58509357338910928)
# train data ('nor gini:', 0.59179212300153117)
# valid data ('nor gini:', 0.54451514830133974)
# mean of all impurity:0.0360239037118
# pass node id shape:(1,)
# pass data shape:(125, 14) (3,)
# not pass data shape:(18147, 14) (66610,)
# all data shape:18272
# mean of all impurity:0.329714865823
# pass node id shape:(78,)
# pass test data shape: 82
# not pass test data shape: 3386
# pass test data ('nor gini:', -0.049180327868852458)
#
# layer: 28
# X_train.shape, y_train.shape:(15424, 14)(15424,)
# X_valid.shape, y_valid.shape:(2723, 14)(2723,)
# all data ('nor gini:', 0.5846130338779818)
# train data ('nor gini:', 0.59292302382927076)
# valid data ('nor gini:', 0.53570208485844029)
# mean of all impurity:0.0341776937618
# pass node id shape:(1,)
# pass data shape:(137, 14) (7,)
# not pass data shape:(18010, 14) (66193,)
# all data shape:18147
# mean of all impurity:0.332085800448
# pass node id shape:(86,)
# pass test data shape: 29
# not pass test data shape: 3357
# pass test data ('nor gini:', -0.094736842105263203)
#
# layer: 29
# X_train.shape, y_train.shape:(15308, 14)(15308,)
# X_valid.shape, y_valid.shape:(2702, 14)(2702,)
# all data ('nor gini:', 0.58113601227417377)
# train data ('nor gini:', 0.58537368431578518)
# valid data ('nor gini:', 0.55625756222957601)
# mean of all impurity:0.019415609381
# pass node id shape:(1,)
# pass data shape:(114, 14) (1,)
# not pass data shape:(17896, 14) (65811,)
# all data shape:18010
# mean of all impurity:0.329854739259
# pass node id shape:(83,)
# pass test data shape: 1
# not pass test data shape: 3356
# pass test data ('nor gini:', nan)
#
# layer: 30
# X_train.shape, y_train.shape:(15211, 14)(15211,)
# X_valid.shape, y_valid.shape:(2685, 14)(2685,)
# all data ('nor gini:', 0.57953044088052053)
# train data ('nor gini:', 0.58093868511077584)
# valid data ('nor gini:', 0.57160684869964551)
# mean of all impurity:0.0162590701424
# pass node id shape:(1,)
# pass data shape:(144, 14) (2,)
# not pass data shape:(17752, 14) (65363,)
# all data shape:17896
# mean of all impurity:0.34899526921
# pass node id shape:(73,)
# pass test data shape: 0
# not pass test data shape: 3356
# pass test data ('nor gini:', nan)
#
# layer: 31
# X_train.shape, y_train.shape:(15089, 14)(15089,)
# X_valid.shape, y_valid.shape:(2663, 14)(2663,)
# all data ('nor gini:', 0.5761144757752853)
# train data ('nor gini:', 0.57689011588855099)
# valid data ('nor gini:', 0.56993514020074476)
# mean of all impurity:0.0186899252403
# pass node id shape:(1,)
# pass data shape:(117, 14) (2,)
# not pass data shape:(17635, 14) (65017,)
# all data shape:17752
# mean of all impurity:0.34318172285
# pass node id shape:(83,)
# pass test data shape: 18
# not pass test data shape: 3338
# pass test data ('nor gini:', -0.29999999999999982)
#
# layer: 32
# X_train.shape, y_train.shape:(14989, 14)(14989,)
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in double_scalars
# X_valid.shape, y_valid.shape:(2646, 14)(2646,)
# all data ('nor gini:', 0.56515212083300959)
# train data ('nor gini:', 0.56785523950590855)
# valid data ('nor gini:', 0.54686166075835219)
# mean of all impurity:0.0629255073039
# pass node id shape:(1,)
# pass data shape:(150, 14) (6,)
# not pass data shape:(17485, 14) (64594,)
# all data shape:17635
# mean of all impurity:0.351165173049
# pass node id shape:(75,)
# pass test data shape: 21
# not pass test data shape: 3317
# pass test data ('nor gini:', 0.52941176470588225)
#
# layer: 33
# X_train.shape, y_train.shape:(14862, 14)(14862,)
# X_valid.shape, y_valid.shape:(2623, 14)(2623,)
# all data ('nor gini:', 0.56943940791057424)
# train data ('nor gini:', 0.57265204628801747)
# valid data ('nor gini:', 0.54736148107170057)
# mean of all impurity:0.0521364795918
# pass node id shape:(1,)
# pass data shape:(129, 14) (5,)
# not pass data shape:(17356, 14) (64233,)
# all data shape:17485
# mean of all impurity:0.341173817546
# pass node id shape:(77,)
# pass test data shape: 56
# not pass test data shape: 3261
# pass test data ('nor gini:', 0.43550446998722869)
#
# layer: 34
# X_train.shape, y_train.shape:(14752, 14)(14752,)
# X_valid.shape, y_valid.shape:(2604, 14)(2604,)
# all data ('nor gini:', 0.56426484512516673)
# train data ('nor gini:', 0.57042137630362411)
# valid data ('nor gini:', 0.52697294302513342)
# mean of all impurity:0.0798611111111
# pass node id shape:(1,)
# pass data shape:(171, 14) (6,)
# not pass data shape:(17185, 14) (63637,)
# all data shape:17356
# mean of all impurity:0.350286127455
# pass node id shape:(78,)
# pass test data shape: 1
# not pass test data shape: 3260
# pass test data ('nor gini:', nan)
#
# layer: 35
# X_train.shape, y_train.shape:(14607, 14)(14607,)
# X_valid.shape, y_valid.shape:(2578, 14)(2578,)
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   if sys.path[0] == '':
# all data ('nor gini:', 0.55874130099461161)
# train data ('nor gini:', 0.56512687706074249)
# valid data ('nor gini:', 0.51815654794378185)
# mean of all impurity:0.0582
# pass node id shape:(1,)
# pass data shape:(113, 14) (3,)
# not pass data shape:(17072, 14) (63239,)
# all data shape:17185
# mean of all impurity:0.343726761635
# pass node id shape:(76,)
# pass test data shape: 44
# not pass test data shape: 3216
# pass test data ('nor gini:', 0.19691119691119688)
#
# layer: 36
# X_train.shape, y_train.shape:(14511, 14)(14511,)
# X_valid.shape, y_valid.shape:(2561, 14)(2561,)
# all data ('nor gini:', 0.55419345210385018)
# train data ('nor gini:', 0.55986297788054906)
# valid data ('nor gini:', 0.52018323336002215)
# mean of all impurity:0.0499671268902
# pass node id shape:(1,)
# pass data shape:(141, 14) (136,)
# not pass data shape:(16931, 14) (62701,)
# all data shape:17072
# mean of all impurity:0.356693324456
# pass node id shape:(84,)
# pass test data shape: 62
# not pass test data shape: 3154
# pass test data ('nor gini:', 0.28846153846153844)
#
# layer: 37
# X_train.shape, y_train.shape:(14391, 14)(14391,)
# X_valid.shape, y_valid.shape:(2540, 14)(2540,)
# all data ('nor gini:', 0.54711056426459403)
# train data ('nor gini:', 0.55341663526054019)
# valid data ('nor gini:', 0.51072129336194771)
# mean of all impurity:0.0360239037118
# pass node id shape:(1,)
# pass data shape:(123, 14) (121,)
# not pass data shape:(16808, 14) (62228,)
# all data shape:16931
# mean of all impurity:0.354985276436
# pass node id shape:(72,)
# pass test data shape: 17
# not pass test data shape: 3137
# pass test data ('nor gini:', -0.17142857142857135)
#
# layer: 38
# X_train.shape, y_train.shape:(14286, 14)(14286,)
# X_valid.shape, y_valid.shape:(2522, 14)(2522,)
# all data ('nor gini:', 0.52849144313687901)
# train data ('nor gini:', 0.53107171786557028)
# valid data ('nor gini:', 0.51587276047383079)
# mean of all impurity:0.0762156714538
# pass node id shape:(1,)
# pass data shape:(145, 14) (6,)
# not pass data shape:(16663, 14) (61709,)
# all data shape:16808
# mean of all impurity:0.346588608602
# pass node id shape:(80,)
# pass test data shape: 49
# not pass test data shape: 3088
# pass test data ('nor gini:', -0.0842105263157895)
#
# layer: 39
# X_train.shape, y_train.shape:(14163, 14)(14163,)
# X_valid.shape, y_valid.shape:(2500, 14)(2500,)
# all data ('nor gini:', 0.52931107568226599)
# train data ('nor gini:', 0.53757600932903227)
# valid data ('nor gini:', 0.48088888888888903)
# mean of all impurity:0.091392
# pass node id shape:(1,)
# pass data shape:(151, 14) (7,)
# not pass data shape:(16512, 14) (61159,)
# all data shape:16663
# mean of all impurity:0.352167871247
# pass node id shape:(73,)
# pass test data shape: 10
# not pass test data shape: 3078
# pass test data ('nor gini:', -0.33333333333333343)
#
# layer: 40
# X_train.shape, y_train.shape:(14035, 14)(14035,)
# X_valid.shape, y_valid.shape:(2477, 14)(2477,)
# all data ('nor gini:', 0.52458550883753585)
# train data ('nor gini:', 0.53308257724250607)
# valid data ('nor gini:', 0.47279825069680281)
# mean of all impurity:0.0437736689686
# pass node id shape:(1,)
# pass data shape:(158, 14) (5,)
# not pass data shape:(16354, 14) (60718,)
# all data shape:16512
# mean of all impurity:0.362070548709
# pass node id shape:(78,)
# pass test data shape: 43
# not pass test data shape: 3035
# pass test data ('nor gini:', 0.27705627705627706)
#
# layer: 41
# X_train.shape, y_train.shape:(13900, 14)(13900,)
# X_valid.shape, y_valid.shape:(2454, 14)(2454,)
# all data ('nor gini:', 0.52076450154151011)
# train data ('nor gini:', 0.52619391180199815)
# valid data ('nor gini:', 0.48756066941117127)
# mean of all impurity:0.0479709755442
# pass node id shape:(1,)
# pass data shape:(136, 14) (6,)
# not pass data shape:(16218, 14) (60169,)
# all data shape:16354
# mean of all impurity:0.360266767566
# pass node id shape:(71,)
# pass test data shape: 10
# not pass test data shape: 3025
# pass test data ('nor gini:', -0.14285714285714288)
#
# layer: 42
# X_train.shape, y_train.shape:(13785, 14)(13785,)
# X_valid.shape, y_valid.shape:(2433, 14)(2433,)
# all data ('nor gini:', 0.51579562838574344)
# train data ('nor gini:', 0.52552922162321003)
# valid data ('nor gini:', 0.46036266722408031)
# mean of all impurity:0.107755102041
# pass node id shape:(1,)
# pass data shape:(118, 14) (8,)
# not pass data shape:(16100, 14) (59727,)
# all data shape:16218
# mean of all impurity:0.362164461641
# pass node id shape:(74,)
# pass test data shape: 128
# not pass test data shape: 2897
# pass test data ('nor gini:', 0.17110834371108355)
#
# layer: 43
# X_train.shape, y_train.shape:(13685, 14)(13685,)
# X_valid.shape, y_valid.shape:(2415, 14)(2415,)
# all data ('nor gini:', 0.51413522062587225)
# train data ('nor gini:', 0.52103747130908618)
# valid data ('nor gini:', 0.47611210382770625)
# mean of all impurity:0.107036869373
# pass node id shape:(1,)
# pass data shape:(174, 14) (12,)
# not pass data shape:(15926, 14) (59246,)
# all data shape:16100
# mean of all impurity:0.368167700532
# pass node id shape:(75,)
# pass test data shape: 67
# not pass test data shape: 2830
# pass test data ('nor gini:', 0.24703557312252949)
#
# layer: 44
# X_train.shape, y_train.shape:(13537, 14)(13537,)
# X_valid.shape, y_valid.shape:(2389, 14)(2389,)
# all data ('nor gini:', 0.50753544696499464)
# train data ('nor gini:', 0.51666288762125456)
# valid data ('nor gini:', 0.45695794333086409)
# mean of all impurity:0.125306304299
# pass node id shape:(1,)
# pass data shape:(152, 14) (10,)
# not pass data shape:(15774, 14) (58806,)
# all data shape:15926
# mean of all impurity:0.376894519553
# pass node id shape:(76,)
# pass test data shape: 21
# not pass test data shape: 2809
# pass test data ('nor gini:', 0.24074074074074078)
#
# layer: 45
# X_train.shape, y_train.shape:(13407, 14)(13407,)
# X_valid.shape, y_valid.shape:(2367, 14)(2367,)
# all data ('nor gini:', 0.49746632532191271)
# train data ('nor gini:', 0.49904855337586679)
# valid data ('nor gini:', 0.48752622918189276)
# mean of all impurity:0.0923743990951
# pass node id shape:(1,)
# pass data shape:(125, 14) (9,)
# not pass data shape:(15649, 14) (58235,)
# all data shape:15774
# mean of all impurity:0.375739968028
# pass node id shape:(70,)
# pass test data shape: 25
# not pass test data shape: 2784
# pass test data ('nor gini:', 0.43055555555555536)
#
# layer: 46
# X_train.shape, y_train.shape:(13301, 14)(13301,)
# X_valid.shape, y_valid.shape:(2348, 14)(2348,)
# all data ('nor gini:', 0.50478831126625379)
# train data ('nor gini:', 0.50946378454911423)
# valid data ('nor gini:', 0.47918001281229977)
# mean of all impurity:0.107179752066
# pass node id shape:(1,)
# pass data shape:(205, 14) (12,)
# not pass data shape:(15444, 14) (57556,)
# all data shape:15649
# mean of all impurity:0.371982890952
# pass node id shape:(71,)
# pass test data shape: 21
# not pass test data shape: 2763
# pass test data ('nor gini:', -0.38235294117647062)
#
# layer: 47
# X_train.shape, y_train.shape:(13127, 14)(13127,)
# X_valid.shape, y_valid.shape:(2317, 14)(2317,)
# all data ('nor gini:', 0.50446168642177702)
# train data ('nor gini:', 0.51437671886965175)
# valid data ('nor gini:', 0.44409344661149724)
# mean of all impurity:0.0932333717801
# pass node id shape:(1,)
# pass data shape:(114, 14) (8,)
# not pass data shape:(15330, 14) (57137,)
# all data shape:15444
# mean of all impurity:0.375094646131
# pass node id shape:(78,)
# pass test data shape: 53
# not pass test data shape: 2710
# pass test data ('nor gini:', -0.29275362318840586)
#
# layer: 48
# X_train.shape, y_train.shape:(13030, 14)(13030,)
# X_valid.shape, y_valid.shape:(2300, 14)(2300,)
# all data ('nor gini:', 0.5028651687298934)
# train data ('nor gini:', 0.51724730064674751)
# valid data ('nor gini:', 0.41790001267559473)
# mean of all impurity:0.076070973434
# pass node id shape:(1,)
# pass data shape:(115, 14) (7,)
# not pass data shape:(15215, 14) (56722,)
# all data shape:15330
# mean of all impurity:0.373597096596
# pass node id shape:(73,)
# pass test data shape: 13
# not pass test data shape: 2697
# pass test data ('nor gini:', 0.64999999999999991)
#
# layer: 49
# X_train.shape, y_train.shape:(12932, 14)(12932,)
# X_valid.shape, y_valid.shape:(2283, 14)(2283,)
# all data ('nor gini:', 0.49686637043060694)
# train data ('nor gini:', 0.50609355825997915)
# valid data ('nor gini:', 0.4433740191804707)
# mean of all impurity:0.0768
# pass node id shape:(1,)
# pass data shape:(114, 14) (108,)
# not pass data shape:(15101, 14) (56360,)
# all data shape:15215
# mean of all impurity:0.380034863615
# pass node id shape:(66,)
# pass test data shape: 39
# not pass test data shape: 2658
# pass test data ('nor gini:', 0.095238095238095288)
#
# layer: 50
# X_train.shape, y_train.shape:(12835, 14)(12835,)
# X_valid.shape, y_valid.shape:(2266, 14)(2266,)
# all data ('nor gini:', 0.49246318728602551)
# train data ('nor gini:', 0.5022578407335887)
# valid data ('nor gini:', 0.43455076145472721)
# mean of all impurity:0.0932333717801
# pass node id shape:(1,)
# pass data shape:(118, 14) (7,)
# not pass data shape:(14983, 14) (55914,)
# all data shape:15101
# mean of all impurity:0.384343103027
# pass node id shape:(69,)
# pass test data shape: 4
# not pass test data shape: 2654
# pass test data ('nor gini:', 1.0)
#
# layer: 51
# X_train.shape, y_train.shape:(12735, 14)(12735,)
# X_valid.shape, y_valid.shape:(2248, 14)(2248,)
# all data ('nor gini:', 0.48843380228234123)
# train data ('nor gini:', 0.49222754275532316)
# valid data ('nor gini:', 0.46655989857030844)
# mean of all impurity:0.105860773867
# pass node id shape:(1,)
# pass data shape:(126, 14) (9,)
# not pass data shape:(14857, 14) (55538,)
# all data shape:14983
# mean of all impurity:0.389992624409
# pass node id shape:(59,)
# pass test data shape: 69
# not pass test data shape: 2585
# pass test data ('nor gini:', -0.064189189189189033)
#
# layer: 52
# X_train.shape, y_train.shape:(12628, 14)(12628,)
# X_valid.shape, y_valid.shape:(2229, 14)(2229,)
# all data ('nor gini:', 0.48074990934106959)
# train data ('nor gini:', 0.49447648227874746)
# valid data ('nor gini:', 0.40066506464496038)
# mean of all impurity:0.1128
# pass node id shape:(1,)
# pass data shape:(116, 14) (8,)
# not pass data shape:(14741, 14) (55140,)
# all data shape:14857
# mean of all impurity:0.382306927969
# pass node id shape:(70,)
# pass test data shape: 88
# not pass test data shape: 2497
# pass test data ('nor gini:', 0.16072472238457036)
#
# layer: 53
# X_train.shape, y_train.shape:(12529, 14)(12529,)
# X_valid.shape, y_valid.shape:(2212, 14)(2212,)
# all data ('nor gini:', 0.47897504304799732)
# train data ('nor gini:', 0.48737470711152392)
# valid data ('nor gini:', 0.43002352150537637)
# mean of all impurity:0.131568642807
# pass node id shape:(1,)
# pass data shape:(136, 14) (10,)
# not pass data shape:(14605, 14) (54606,)
# all data shape:14741
# mean of all impurity:0.386908606358
# pass node id shape:(71,)
# pass test data shape: 48
# not pass test data shape: 2449
# pass test data ('nor gini:', 0.43277310924369772)
#
# layer: 54
# X_train.shape, y_train.shape:(12414, 14)(12414,)
# X_valid.shape, y_valid.shape:(2191, 14)(2191,)
# all data ('nor gini:', 0.47582709726501521)
# train data ('nor gini:', 0.48663405597173981)
# valid data ('nor gini:', 0.41192906008976421)
# mean of all impurity:0.103140495868
# pass node id shape:(1,)
# pass data shape:(125, 14) (9,)
# not pass data shape:(14480, 14) (54245,)
# all data shape:14605
# mean of all impurity:0.389402352843
# pass node id shape:(61,)
# pass test data shape: 6
# not pass test data shape: 2443
# pass test data ('nor gini:', 0.19999999999999998)
#
# layer: 55
# X_train.shape, y_train.shape:(12308, 14)(12308,)
# X_valid.shape, y_valid.shape:(2172, 14)(2172,)
# all data ('nor gini:', 0.46832524000101516)
# train data ('nor gini:', 0.47751652928990168)
# valid data ('nor gini:', 0.4134403014448656)
# mean of all impurity:0.161328216775
# pass node id shape:(1,)
# pass data shape:(131, 14) (13,)
# not pass data shape:(14349, 14) (53903,)
# all data shape:14480
# mean of all impurity:0.395869080135
# pass node id shape:(64,)
# pass test data shape: 27
# not pass test data shape: 2416
# pass test data ('nor gini:', 0.4320987654320988)
#
# layer: 56
# X_train.shape, y_train.shape:(12196, 14)(12196,)
# X_valid.shape, y_valid.shape:(2153, 14)(2153,)
# all data ('nor gini:', 0.46835563656047818)
# train data ('nor gini:', 0.46909834062737171)
# valid data ('nor gini:', 0.46375811797677124)
# mean of all impurity:0.138115393183
# pass node id shape:(1,)
# pass data shape:(158, 14) (14,)
# not pass data shape:(14191, 14) (53380,)
# all data shape:14349
# mean of all impurity:0.387416684847
# pass node id shape:(54,)
# pass test data shape: 0
# not pass test data shape: 2416
# pass test data ('nor gini:', nan)
#
# layer: 57
# X_train.shape, y_train.shape:(12062, 14)(12062,)
# X_valid.shape, y_valid.shape:(2129, 14)(2129,)
# all data ('nor gini:', 0.45780653255981651)
# train data ('nor gini:', 0.46407064018416005)
# valid data ('nor gini:', 0.42220915449352764)
# mean of all impurity:0.115266235765
# pass node id shape:(1,)
# pass data shape:(136, 14) (12,)
# not pass data shape:(14055, 14) (52861,)
# all data shape:14191
# mean of all impurity:0.412734012378
# pass node id shape:(64,)
# pass test data shape: 165
# not pass test data shape: 2251
# pass test data ('nor gini:', 0.49301587301587313)
#
# layer: 58
# X_train.shape, y_train.shape:(11946, 14)(11946,)
# X_valid.shape, y_valid.shape:(2109, 14)(2109,)
# all data ('nor gini:', 0.46297592037415874)
# train data ('nor gini:', 0.46969783295992656)
# valid data ('nor gini:', 0.42288614668218871)
# mean of all impurity:0.156734693878
# pass node id shape:(1,)
# pass data shape:(167, 14) (18,)
# not pass data shape:(13888, 14) (52263,)
# all data shape:14055
# mean of all impurity:0.401555326714
# pass node id shape:(62,)
# pass test data shape: 28
# not pass test data shape: 2223
# pass test data ('nor gini:', 0.29824561403508787)
#
# layer: 59
# X_train.shape, y_train.shape:(11804, 14)(11804,)
# X_valid.shape, y_valid.shape:(2084, 14)(2084,)
# all data ('nor gini:', 0.46071374110543617)
# train data ('nor gini:', 0.46315869461068854)
# valid data ('nor gini:', 0.44572288807167409)
# mean of all impurity:0.166088565152
# pass node id shape:(1,)
# pass data shape:(220, 14) (194,)
# not pass data shape:(13668, 14) (51264,)
# all data shape:13888
# mean of all impurity:0.409448568851
# pass node id shape:(59,)
# pass test data shape: 92
# not pass test data shape: 2131
# pass test data ('nor gini:', 0.34135338345864663)
#
# layer: 60
# X_train.shape, y_train.shape:(11617, 14)(11617,)
# X_valid.shape, y_valid.shape:(2051, 14)(2051,)
# all data ('nor gini:', 0.44660026090076504)
# train data ('nor gini:', 0.450492304556738)
# valid data ('nor gini:', 0.42270273687870968)
# mean of all impurity:0.21617564271
# pass node id shape:(1,)
# pass data shape:(176, 14) (22,)
# not pass data shape:(13492, 14) (50593,)
# all data shape:13668
# mean of all impurity:0.412334211915
# pass node id shape:(60,)
# pass test data shape: 51
# not pass test data shape: 2080
# pass test data ('nor gini:', 0.35907335907335924)
#
# layer: 61
# X_train.shape, y_train.shape:(11468, 14)(11468,)
# X_valid.shape, y_valid.shape:(2024, 14)(2024,)
# all data ('nor gini:', 0.44336607793153687)
# train data ('nor gini:', 0.45239918846716054)
# valid data ('nor gini:', 0.38706310679611644)
# mean of all impurity:0.222963423597
# pass node id shape:(1,)
# pass data shape:(156, 14) (25,)
# not pass data shape:(13336, 14) (50066,)
# all data shape:13492
# mean of all impurity:0.416964064052
# pass node id shape:(52,)
# pass test data shape: 156
# not pass test data shape: 1924
# pass test data ('nor gini:', 0.41209893048128327)
#
# layer: 62
# X_train.shape, y_train.shape:(11335, 14)(11335,)
# X_valid.shape, y_valid.shape:(2001, 14)(2001,)
# all data ('nor gini:', 0.43266093865611666)
# train data ('nor gini:', 0.43795966528799263)
# valid data ('nor gini:', 0.39855228103508794)
# mean of all impurity:0.2112
# pass node id shape:(1,)
# pass data shape:(122, 14) (18,)
# not pass data shape:(13214, 14) (49697,)
# all data shape:13336
# mean of all impurity:0.410995530363
# pass node id shape:(54,)
# pass test data shape: 2
# not pass test data shape: 1922
# pass test data ('nor gini:', nan)
#
# layer: 63
# X_train.shape, y_train.shape:(11231, 14)(11231,)
# X_valid.shape, y_valid.shape:(1983, 14)(1983,)
# all data ('nor gini:', 0.43232977996399818)
# train data ('nor gini:', 0.43572610143761076)
# valid data ('nor gini:', 0.41359958865441715)
# mean of all impurity:0.18836565097
# pass node id shape:(1,)
# pass data shape:(132, 14) (16,)
# not pass data shape:(13082, 14) (49224,)
# all data shape:13214
# mean of all impurity:0.411867011287
# pass node id shape:(55,)
# pass test data shape: 14
# not pass test data shape: 1908
# pass test data ('nor gini:', 0.59999999999999976)
#
# layer: 64
# X_train.shape, y_train.shape:(11119, 14)(11119,)
# X_valid.shape, y_valid.shape:(1963, 14)(1963,)
# all data ('nor gini:', 0.42929666968156066)
# train data ('nor gini:', 0.44094638736659691)
# valid data ('nor gini:', 0.36352151514503767)
# mean of all impurity:0.156734693878
# pass node id shape:(1,)
# pass data shape:(124, 14) (11,)
# not pass data shape:(12958, 14) (48825,)
# all data shape:13082
# mean of all impurity:0.416752540186
# pass node id shape:(63,)
# pass test data shape: 80
# not pass test data shape: 1828
# pass test data ('nor gini:', 0.16153362664990584)
#
# layer: 65
# X_train.shape, y_train.shape:(11014, 14)(11014,)
# X_valid.shape, y_valid.shape:(1944, 14)(1944,)
# all data ('nor gini:', 0.42545766794243151)
# train data ('nor gini:', 0.43892242191862674)
# valid data ('nor gini:', 0.34759321068011745)
# mean of all impurity:0.200312174818
# pass node id shape:(1,)
# pass data shape:(142, 14) (21,)
# not pass data shape:(12816, 14) (48314,)
# all data shape:12958
# mean of all impurity:0.420871187512
# pass node id shape:(55,)
# pass test data shape: 94
# not pass test data shape: 1734
# pass test data ('nor gini:', 0.099300699300699402)
#
# layer: 66
# X_train.shape, y_train.shape:(10893, 14)(10893,)
# X_valid.shape, y_valid.shape:(1923, 14)(1923,)
# all data ('nor gini:', 0.4201190733765619)
# train data ('nor gini:', 0.42917479392193175)
# valid data ('nor gini:', 0.36364402737568347)
# mean of all impurity:0.220567442737
# pass node id shape:(1,)
# pass data shape:(129, 14) (19,)
# not pass data shape:(12687, 14) (47967,)
# all data shape:12816
# mean of all impurity:0.426170544317
# pass node id shape:(57,)
# pass test data shape: 114
# not pass test data shape: 1620
# pass test data ('nor gini:', 0.38709677419354838)
#
# layer: 67
# X_train.shape, y_train.shape:(10783, 14)(10783,)
# X_valid.shape, y_valid.shape:(1904, 14)(1904,)
# all data ('nor gini:', 0.41540343747289565)
# train data ('nor gini:', 0.42561980531948529)
# valid data ('nor gini:', 0.35359452916094536)
# mean of all impurity:0.224081632653
# pass node id shape:(1,)
# pass data shape:(162, 14) (23,)
# not pass data shape:(12525, 14) (47430,)
# all data shape:12687
# mean of all impurity:0.428914257579
# pass node id shape:(48,)
# pass test data shape: 71
# not pass test data shape: 1549
# pass test data ('nor gini:', -0.13036565977742459)
#
# layer: 68
# X_train.shape, y_train.shape:(10646, 14)(10646,)
# X_valid.shape, y_valid.shape:(1879, 14)(1879,)
# all data ('nor gini:', 0.41316813129863061)
# train data ('nor gini:', 0.4272204892464293)
# valid data ('nor gini:', 0.33550850399166948)
# mean of all impurity:0.225651577503
# pass node id shape:(1,)
# pass data shape:(126, 14) (107,)
# not pass data shape:(12399, 14) (47048,)
# all data shape:12525
# mean of all impurity:0.432023766575
# pass node id shape:(54,)
# pass test data shape: 75
# not pass test data shape: 1474
# pass test data ('nor gini:', 0.13489736070381236)
#
# layer: 69
# X_train.shape, y_train.shape:(10539, 14)(10539,)
# X_valid.shape, y_valid.shape:(1860, 14)(1860,)
# all data ('nor gini:', 0.40358328650723019)
# train data ('nor gini:', 0.40872686107054879)
# valid data ('nor gini:', 0.37878343056292152)
# mean of all impurity:0.222414455978
# pass node id shape:(1,)
# pass data shape:(120, 14) (19,)
# not pass data shape:(12279, 14) (46603,)
# all data shape:12399
# mean of all impurity:0.42175585963
# pass node id shape:(46,)
# pass test data shape: 18
# not pass test data shape: 1456
# pass test data ('nor gini:', 0.29999999999999982)
#
# layer: 70
# X_train.shape, y_train.shape:(10437, 14)(10437,)
# X_valid.shape, y_valid.shape:(1842, 14)(1842,)
# all data ('nor gini:', 0.39765253140632068)
# train data ('nor gini:', 0.41514892110355806)
# valid data ('nor gini:', 0.29824464142598006)
# mean of all impurity:0.237353758101
# pass node id shape:(1,)
# pass data shape:(132, 14) (25,)
# not pass data shape:(12147, 14) (46176,)
# all data shape:12279
# mean of all impurity:0.427363510274
# pass node id shape:(50,)
# pass test data shape: 97
# not pass test data shape: 1359
# pass test data ('nor gini:', 0.3393626184323858)
#
# layer: 71
# X_train.shape, y_train.shape:(10324, 14)(10324,)
# X_valid.shape, y_valid.shape:(1823, 14)(1823,)
# all data ('nor gini:', 0.39136736657760868)
# train data ('nor gini:', 0.39581976290108545)
# valid data ('nor gini:', 0.3695001117850974)
# mean of all impurity:0.172335600907
# pass node id shape:(1,)
# pass data shape:(141, 14) (17,)
# not pass data shape:(12006, 14) (45565,)
# all data shape:12147
# mean of all impurity:0.435428070183
# pass node id shape:(43,)
# pass test data shape: 72
# not pass test data shape: 1287
# pass test data ('nor gini:', -0.076190476190476253)
#
# layer: 72
# X_train.shape, y_train.shape:(10205, 14)(10205,)
# X_valid.shape, y_valid.shape:(1801, 14)(1801,)
# all data ('nor gini:', 0.39429118035857824)
# train data ('nor gini:', 0.40044085156703491)
# valid data ('nor gini:', 0.36001296257683946)
# mean of all impurity:0.238217991936
# pass node id shape:(1,)
# pass data shape:(150, 14) (20,)
# not pass data shape:(11856, 14) (44982,)
# all data shape:12006
# mean of all impurity:0.439001277842
# pass node id shape:(50,)
# pass test data shape: 219
# not pass test data shape: 1068
# pass test data ('nor gini:', 0.02226345083487951)
#
# layer: 73
# X_train.shape, y_train.shape:(10077, 14)(10077,)
# X_valid.shape, y_valid.shape:(1779, 14)(1779,)
# all data ('nor gini:', 0.39183534199921399)
# train data ('nor gini:', 0.4039956928431761)
# valid data ('nor gini:', 0.32508659588245553)
# mean of all impurity:0.239197530864
# pass node id shape:(1,)
# pass data shape:(118, 14) (101,)
# not pass data shape:(11738, 14) (44612,)
# all data shape:11856
# mean of all impurity:0.429847577994
# pass node id shape:(41,)
# pass test data shape: 19
# not pass test data shape: 1049
# pass test data ('nor gini:', 0.11363636363636362)
#
# layer: 74
# X_train.shape, y_train.shape:(9977, 14)(9977,)
# X_valid.shape, y_valid.shape:(1761, 14)(1761,)
# all data ('nor gini:', 0.39454121010117504)
# train data ('nor gini:', 0.4049735557013901)
# valid data ('nor gini:', 0.33752693823915886)
# mean of all impurity:0.268422067901
# pass node id shape:(1,)
# pass data shape:(176, 14) (37,)
# not pass data shape:(11562, 14) (44139,)
# all data shape:11738
# mean of all impurity:0.438722423118
# pass node id shape:(52,)
# pass test data shape: 44
# not pass test data shape: 1005
# pass test data ('nor gini:', -0.19080459770114935)
#
# layer: 75
# X_train.shape, y_train.shape:(9827, 14)(9827,)
# X_valid.shape, y_valid.shape:(1735, 14)(1735,)
# all data ('nor gini:', 0.38841800039482116)
# train data ('nor gini:', 0.39643488994432768)
# valid data ('nor gini:', 0.34231923232869305)
# mean of all impurity:0.246293863764
# pass node id shape:(1,)
# pass data shape:(177, 14) (27,)
# not pass data shape:(11385, 14) (43481,)
# all data shape:11562
# mean of all impurity:0.438707767814
# pass node id shape:(44,)
# pass test data shape: 119
# not pass test data shape: 886
# pass test data ('nor gini:', 0.12364672364672367)
#
# layer: 76
# X_train.shape, y_train.shape:(9677, 14)(9677,)
# X_valid.shape, y_valid.shape:(1708, 14)(1708,)
# all data ('nor gini:', 0.38282206829152554)
# train data ('nor gini:', 0.3915729146303456)
# valid data ('nor gini:', 0.33198368737190531)
# mean of all impurity:0.252995918367
# pass node id shape:(1,)
# pass data shape:(204, 14) (35,)
# not pass data shape:(11181, 14) (42603,)
# all data shape:11385
# mean of all impurity:0.439573393537
# pass node id shape:(45,)
# pass test data shape: 87
# not pass test data shape: 799
# pass test data ('nor gini:', 0.3582417582417583)
#
# layer: 77
# X_train.shape, y_train.shape:(9503, 14)(9503,)
# X_valid.shape, y_valid.shape:(1678, 14)(1678,)
# all data ('nor gini:', 0.38645250342485626)
# train data ('nor gini:', 0.39801951160449411)
# valid data ('nor gini:', 0.32145692621017391)
# mean of all impurity:0.186009255963
# pass node id shape:(1,)
# pass data shape:(121, 14) (103,)
# not pass data shape:(11060, 14) (42204,)
# all data shape:11181
# mean of all impurity:0.438860276591
# pass node id shape:(52,)
# pass test data shape: 111
# not pass test data shape: 688
# pass test data ('nor gini:', 0.0)
#
# layer: 78
# X_train.shape, y_train.shape:(9401, 14)(9401,)
# X_valid.shape, y_valid.shape:(1659, 14)(1659,)
# all data ('nor gini:', 0.36794873019816166)
# train data ('nor gini:', 0.37740614577064663)
# valid data ('nor gini:', 0.31251751035875963)
# mean of all impurity:0.273219491878
# pass node id shape:(1,)
# pass data shape:(171, 14) (30,)
# not pass data shape:(10889, 14) (41581,)
# all data shape:11060
# mean of all impurity:0.445932917379
# pass node id shape:(55,)
# pass test data shape: 17
# not pass test data shape: 671
# pass test data ('nor gini:', -0.33333333333333337)
#
# layer: 79
# X_train.shape, y_train.shape:(9255, 14)(9255,)
# X_valid.shape, y_valid.shape:(1634, 14)(1634,)
# all data ('nor gini:', 0.37754428408548002)
# train data ('nor gini:', 0.38390012566663467)
# valid data ('nor gini:', 0.33811179475977227)
# mean of all impurity:0.290048
# pass node id shape:(1,)
# pass data shape:(143, 14) (117,)
# not pass data shape:(10746, 14) (41112,)
# all data shape:10889
# mean of all impurity:0.44244632472
# pass node id shape:(44,)
# pass test data shape: 2
# not pass test data shape: 669
# pass test data ('nor gini:', nan)
#
# layer: 80
# X_train.shape, y_train.shape:(9134, 14)(9134,)
# X_valid.shape, y_valid.shape:(1612, 14)(1612,)
# all data ('nor gini:', 0.36380600143615394)
# train data ('nor gini:', 0.37843465483906463)
# valid data ('nor gini:', 0.28034848257587119)
# mean of all impurity:0.285603854776
# pass node id shape:(1,)
# pass data shape:(225, 14) (44,)
# not pass data shape:(10521, 14) (40238,)
# all data shape:10746
# mean of all impurity:0.450062037457
# pass node id shape:(45,)
# pass test data shape: 17
# not pass test data shape: 652
# pass test data ('nor gini:', 0.33333333333333337)
#
# layer: 81
# X_train.shape, y_train.shape:(8942, 14)(8942,)
# X_valid.shape, y_valid.shape:(1579, 14)(1579,)
# all data ('nor gini:', 0.35738216507097742)
# train data ('nor gini:', 0.36727407176674237)
# valid data ('nor gini:', 0.30181238162994145)
# mean of all impurity:0.292077910735
# pass node id shape:(1,)
# pass data shape:(129, 14) (26,)
# not pass data shape:(10392, 14) (39707,)
# all data shape:10521
# mean of all impurity:0.453789013668
# pass node id shape:(42,)
# pass test data shape: 2
# not pass test data shape: 650
# pass test data ('nor gini:', 1.0)
#
# layer: 82
# X_train.shape, y_train.shape:(8833, 14)(8833,)
# X_valid.shape, y_valid.shape:(1559, 14)(1559,)
# all data ('nor gini:', 0.35398459203866933)
# train data ('nor gini:', 0.36730206981209534)
# valid data ('nor gini:', 0.27866910269593897)
# mean of all impurity:0.284361773223
# pass node id shape:(1,)
# pass data shape:(158, 14) (26,)
# not pass data shape:(10234, 14) (39203,)
# all data shape:10392
# mean of all impurity:0.454901892503
# pass node id shape:(49,)
# pass test data shape: 103
# not pass test data shape: 547
# pass test data ('nor gini:', 0.19365079365079371)
#
# layer: 83
# X_train.shape, y_train.shape:(8698, 14)(8698,)
# X_valid.shape, y_valid.shape:(1536, 14)(1536,)
# all data ('nor gini:', 0.34634457170666838)
# train data ('nor gini:', 0.36116373287755837)
# valid data ('nor gini:', 0.26350051681532227)
# mean of all impurity:0.295430565701
# pass node id shape:(1,)
# pass data shape:(134, 14) (24,)
# not pass data shape:(10100, 14) (38852,)
# all data shape:10234
# mean of all impurity:0.45411643649
# pass node id shape:(50,)
# pass test data shape: 27
# not pass test data shape: 520
# pass test data ('nor gini:', 0.58024691358024694)
#
# layer: 84
# X_train.shape, y_train.shape:(8585, 14)(8585,)
# X_valid.shape, y_valid.shape:(1515, 14)(1515,)
# all data ('nor gini:', 0.33849093662640195)
# train data ('nor gini:', 0.34771122166536617)
# valid data ('nor gini:', 0.28425120772946849)
# mean of all impurity:0.308925619835
# pass node id shape:(1,)
# pass data shape:(125, 14) (24,)
# not pass data shape:(9975, 14) (38391,)
# all data shape:10100
# mean of all impurity:0.459387456206
# pass node id shape:(41,)
# pass test data shape: 45
# not pass test data shape: 475
# pass test data ('nor gini:', 0.26482213438735192)
#
# layer: 85
# X_train.shape, y_train.shape:(8478, 14)(8478,)
# X_valid.shape, y_valid.shape:(1497, 14)(1497,)
# all data ('nor gini:', 0.33294361363335173)
# train data ('nor gini:', 0.33543019344080788)
# valid data ('nor gini:', 0.31944579222599606)
# mean of all impurity:0.323228634039
# pass node id shape:(1,)
# pass data shape:(170, 14) (39,)
# not pass data shape:(9805, 14) (37778,)
# all data shape:9975
# mean of all impurity:0.461435940451
# pass node id shape:(42,)
# pass test data shape: 18
# not pass test data shape: 457
# pass test data ('nor gini:', -0.52500000000000002)
#
# layer: 86
# X_train.shape, y_train.shape:(8334, 14)(8334,)
# X_valid.shape, y_valid.shape:(1471, 14)(1471,)
# all data ('nor gini:', 0.33230205149887998)
# train data ('nor gini:', 0.34092141153682165)
# valid data ('nor gini:', 0.28638450528820253)
# mean of all impurity:0.305460248995
# pass node id shape:(1,)
# pass data shape:(114, 14) (27,)
# not pass data shape:(9691, 14) (37354,)
# all data shape:9805
# mean of all impurity:0.461856561785
# pass node id shape:(39,)
# pass test data shape: 4
# not pass test data shape: 453
# pass test data ('nor gini:', -1.0)
#
# layer: 87
# X_train.shape, y_train.shape:(8237, 14)(8237,)
# X_valid.shape, y_valid.shape:(1454, 14)(1454,)
# all data ('nor gini:', 0.33082109883262617)
# train data ('nor gini:', 0.34836126219721925)
# valid data ('nor gini:', 0.23295103501898179)
# mean of all impurity:0.312174817898
# pass node id shape:(1,)
# pass data shape:(137, 14) (27,)
# not pass data shape:(9554, 14) (36867,)
# all data shape:9691
# mean of all impurity:0.460206946138
# pass node id shape:(43,)
# pass test data shape: 21
# not pass test data shape: 432
# pass test data ('nor gini:', 0.12962962962962979)
#
# layer: 88
# X_train.shape, y_train.shape:(8120, 14)(8120,)
# X_valid.shape, y_valid.shape:(1434, 14)(1434,)
# all data ('nor gini:', 0.33080371674346837)
# train data ('nor gini:', 0.34386706191035371)
# valid data ('nor gini:', 0.26213065236364919)
# mean of all impurity:0.3542
# pass node id shape:(1,)
# pass data shape:(112, 14) (27,)
# not pass data shape:(9442, 14) (36503,)
# all data shape:9554
# mean of all impurity:0.462079864937
# pass node id shape:(32,)
# pass test data shape: 15
# not pass test data shape: 417
# pass test data ('nor gini:', 0.0)
#
# layer: 89
# X_train.shape, y_train.shape:(8025, 14)(8025,)
# X_valid.shape, y_valid.shape:(1417, 14)(1417,)
# all data ('nor gini:', 0.32465451098640336)
# train data ('nor gini:', 0.33223882032848351)
# valid data ('nor gini:', 0.28250321734890438)
# mean of all impurity:0.346402249723
# pass node id shape:(1,)
# pass data shape:(396, 14) (304,)
# not pass data shape:(9046, 14) (34665,)
# all data shape:9442
# mean of all impurity:0.467175040065
# pass node id shape:(41,)
# pass test data shape: 6
# not pass test data shape: 411
# pass test data ('nor gini:', -0.33333333333333331)
#
# layer: 90
# X_train.shape, y_train.shape:(7689, 14)(7689,)
# X_valid.shape, y_valid.shape:(1357, 14)(1357,)
# all data ('nor gini:', 0.31472268894826033)
# train data ('nor gini:', 0.33006408846101187)
# valid data ('nor gini:', 0.22607493844061222)
# mean of all impurity:0.298437893676
# pass node id shape:(1,)
# pass data shape:(138, 14) (110,)
# not pass data shape:(8908, 14) (34104,)
# all data shape:9046
# mean of all impurity:0.462496048919
# pass node id shape:(34,)
# pass test data shape: 71
# not pass test data shape: 340
# pass test data ('nor gini:', 0.18589743589743588)
#
# layer: 91
# X_train.shape, y_train.shape:(7571, 14)(7571,)
# X_valid.shape, y_valid.shape:(1337, 14)(1337,)
# all data ('nor gini:', 0.29884847854729168)
# train data ('nor gini:', 0.30730018454573743)
# valid data ('nor gini:', 0.25043442937419608)
# mean of all impurity:0.295430565701
# pass node id shape:(1,)
# pass data shape:(127, 14) (27,)
# not pass data shape:(8781, 14) (33677,)
# all data shape:8908
# mean of all impurity:0.462008427955
# pass node id shape:(35,)
# pass test data shape: 19
# not pass test data shape: 321
# pass test data ('nor gini:', 0.047619047619047748)
#
# layer: 92
# X_train.shape, y_train.shape:(7463, 14)(7463,)
# X_valid.shape, y_valid.shape:(1318, 14)(1318,)
# all data ('nor gini:', 0.29801570214420398)
# train data ('nor gini:', 0.30563575001899063)
# valid data ('nor gini:', 0.25766041586937122)
# mean of all impurity:0.344976756198
# pass node id shape:(1,)
# pass data shape:(205, 14) (162,)
# not pass data shape:(8576, 14) (32756,)
# all data shape:8781
# mean of all impurity:0.469490061926
# pass node id shape:(40,)
# pass test data shape: 3
# not pass test data shape: 318
# pass test data ('nor gini:', -1.0)
#
# layer: 93
# X_train.shape, y_train.shape:(7289, 14)(7289,)
# X_valid.shape, y_valid.shape:(1287, 14)(1287,)
# all data ('nor gini:', 0.27318515040837227)
# train data ('nor gini:', 0.28965173321016829)
# valid data ('nor gini:', 0.18541637180882481)
# mean of all impurity:0.338933528123
# pass node id shape:(1,)
# pass data shape:(130, 14) (31,)
# not pass data shape:(8446, 14) (32206,)
# all data shape:8576
# mean of all impurity:0.46719865088
# pass node id shape:(37,)
# pass test data shape: 50
# not pass test data shape: 268
# pass test data ('nor gini:', 0.33333333333333315)
#
# layer: 94
# X_train.shape, y_train.shape:(7179, 14)(7179,)
# X_valid.shape, y_valid.shape:(1267, 14)(1267,)
# all data ('nor gini:', 0.27830080454441725)
# train data ('nor gini:', 0.30353591636157179)
# valid data ('nor gini:', 0.14023970105265282)
# mean of all impurity:0.339800640797
# pass node id shape:(1,)
# pass data shape:(130, 14) (35,)
# not pass data shape:(8316, 14) (31742,)
# all data shape:8446
# mean of all impurity:0.465089949878
# pass node id shape:(37,)
# pass test data shape: 55
# not pass test data shape: 213
# pass test data ('nor gini:', 0.39318885448916402)
#
# layer: 95
# X_train.shape, y_train.shape:(7068, 14)(7068,)
# X_valid.shape, y_valid.shape:(1248, 14)(1248,)
# all data ('nor gini:', 0.29001221077533285)
# train data ('nor gini:', 0.30880815717772236)
# valid data ('nor gini:', 0.18666632145816062)
# mean of all impurity:0.303152633602
# pass node id shape:(1,)
# pass data shape:(124, 14) (25,)
# not pass data shape:(8192, 14) (31160,)
# all data shape:8316
# mean of all impurity:0.465465322505
# pass node id shape:(38,)
# pass test data shape: 34
# not pass test data shape: 179
# pass test data ('nor gini:', 0.25694444444444464)
#
# layer: 96
# X_train.shape, y_train.shape:(6963, 14)(6963,)
# X_valid.shape, y_valid.shape:(1229, 14)(1229,)
# all data ('nor gini:', 0.29313603411237504)
# train data ('nor gini:', 0.31380635473532181)
# valid data ('nor gini:', 0.17855315065572008)
# mean of all impurity:0.312941841832
# pass node id shape:(1,)
# pass data shape:(129, 14) (100,)
# not pass data shape:(8063, 14) (30717,)
# all data shape:8192
# mean of all impurity:0.466890517085
# pass node id shape:(33,)
# pass test data shape: 16
# not pass test data shape: 163
# pass test data ('nor gini:', 0.090909090909090912)
#
# layer: 97
# X_train.shape, y_train.shape:(6853, 14)(6853,)
# X_valid.shape, y_valid.shape:(1210, 14)(1210,)
# all data ('nor gini:', 0.26780582235127687)
# train data ('nor gini:', 0.28860359609778552)
# valid data ('nor gini:', 0.15366942148760343)
# mean of all impurity:0.322300295858
# pass node id shape:(1,)
# pass data shape:(125, 14) (24,)
# not pass data shape:(7938, 14) (30262,)
# all data shape:8063
# mean of all impurity:0.468420499419
# pass node id shape:(30,)
# pass test data shape: 3
# not pass test data shape: 160
# pass test data ('nor gini:', 0.0)
#
# layer: 98
# X_train.shape, y_train.shape:(6747, 14)(6747,)
# X_valid.shape, y_valid.shape:(1191, 14)(1191,)
# all data ('nor gini:', 0.29561678390284996)
# train data ('nor gini:', 0.31680467096367299)
# valid data ('nor gini:', 0.17717011670500057)
# mean of all impurity:0.324417009602
# pass node id shape:(1,)
# pass data shape:(125, 14) (29,)
# not pass data shape:(7813, 14) (29854,)
# all data shape:7938
# mean of all impurity:0.468231245162
# pass node id shape:(32,)
# pass test data shape: 17
# not pass test data shape: 143
# pass test data ('nor gini:', 0.16666666666666652)
#
# layer: 99
# X_train.shape, y_train.shape:(6641, 14)(6641,)
# X_valid.shape, y_valid.shape:(1172, 14)(1172,)
# all data ('nor gini:', 0.28634908583303176)
# train data ('nor gini:', 0.30582968526442894)
# valid data ('nor gini:', 0.17808235225209407)
# mean of all impurity:0.362317419861
# pass node id shape:(1,)
# pass data shape:(125, 14) (28,)
# not pass data shape:(7688, 14) (29383,)
# all data shape:7813
# mean of all impurity:0.472560052558
# pass node id shape:(30,)
# pass test data shape: 11
# not pass test data shape: 132
# pass test data ('nor gini:', -0.33333333333333326)
#
# layer: 100
# X_train.shape, y_train.shape:(6534, 14)(6534,)
# X_valid.shape, y_valid.shape:(1154, 14)(1154,)
# all data ('nor gini:', 0.26349926283471264)
# train data ('nor gini:', 0.28317607280422008)
# valid data ('nor gini:', 0.15563897069473281)
# mean of all impurity:0.3542
# pass node id shape:(1,)
# pass data shape:(115, 14) (27,)
# not pass data shape:(7573, 14) (29033,)
# all data shape:7688
# mean of all impurity:0.474840019697
# pass node id shape:(32,)
# pass test data shape: 27
# not pass test data shape: 105
# pass test data ('nor gini:', 0.62222222222222234)
#
# layer: 101
# X_train.shape, y_train.shape:(6437, 14)(6437,)
# X_valid.shape, y_valid.shape:(1136, 14)(1136,)
# all data ('nor gini:', 0.26968935150472662)
# train data ('nor gini:', 0.28470862285649506)
# valid data ('nor gini:', 0.18655627428834565)
# mean of all impurity:0.383194444444
# pass node id shape:(1,)
# pass data shape:(145, 14) (102,)
# not pass data shape:(7428, 14) (28472,)
# all data shape:7573
# mean of all impurity:0.475056964483
# pass node id shape:(34,)
# pass test data shape: 46
# not pass test data shape: 59
# pass test data ('nor gini:', -0.15809523809523812)
# 59

# %% [markdown]
# ### Todo list
# - 树结构设计（完成）
# - 通过gini对数据分割（完成）
# - 全局测试集
# - 输出结果集
# - 打印信息增加pass data的比例
# - 防止过拟合
# - 对pass data的进一步处理
# - 先进行数据均衡化是不是更快一些
