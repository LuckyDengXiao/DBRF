# %% [markdown]
# EcoForest 0.8
#
# > **0.7的精华版，0.8是一个里程碑，将在其基础上做最后的修改**
#
# - 数据地址：UCI
#   - Letter: https://archive.ics.uci.edu/ml/datasets/letter+recognition
# - 数据特点：
#   - 非常不均衡、缺失值严重、二分类
# - 包含内容：
#   1. 数据获取
#   2. 模型应用
#   3. 结果分析

# %%
import os
import numpy as np
import pandas as pd
import time
import os.path as osp

# %% [markdown]
# # Stage-1：获取数据

# %%
import DataHelper
import importlib
from collections import Counter
importlib.reload(DataHelper)
# Out:
# <module 'DataHelper' from 'C:\\Users\\dxeec\\Desktop\\EcoForest-master\\DataHelper.py'>

# %%
# X_train,y_train, X_sub, y_sub = DataHelper.get_driver_data()
# X_train,y_train, X_sub, y_sub = DataHelper.get_yeast_data()
# X_train,y_train, X_sub, y_sub = DataHelper.get_letter_data()

# %%
X_train,y_train, X_sub, y_sub = DataHelper.get_adult_data()
# Out:
# X.shape: (32561, 14) y.shape: (32561,)
# X.shape: (16281, 14) y.shape: (16281,)

# %%
# train = pd.read_csv("./datasetes/adult/adult_train.csv")
# X_train = train.iloc[:, 1:].values 
# y_train = train.iloc[:, 0].values
# X_train.shape, y_train.shape

# %%
# test = pd.read_csv("./datasetes/adult/adult_test.csv")
# X_sub = test.iloc[:, 1:].values 
# y_sub = test.iloc[:, 0].values
# X_sub.shape, y_sub.shape

# %%
Counter(y_train)
# Out:
# Counter({0: 24720, 1: 7841})

# %%
Counter(y_sub)
# Out:
# Counter({0: 12435, 1: 3846})

# %%
print(X_train)
# Out:
# [[3.90000e+01 6.00000e+00 7.75160e+04 ... 0.00000e+00 4.00000e+01
#   1.00000e+00]
#  [5.00000e+01 2.00000e+00 8.33110e+04 ... 0.00000e+00 1.30000e+01
#   1.00000e+00]
#  [3.80000e+01 1.00000e+00 2.15646e+05 ... 0.00000e+00 4.00000e+01
#   1.00000e+00]
#  ...
#  [5.80000e+01 1.00000e+00 1.51910e+05 ... 0.00000e+00 4.00000e+01
#   1.00000e+00]
#  [2.20000e+01 1.00000e+00 2.01490e+05 ... 0.00000e+00 2.00000e+01
#   1.00000e+00]
#  [5.20000e+01 3.00000e+00 2.87927e+05 ... 0.00000e+00 4.00000e+01
#   1.00000e+00]]

# %% [markdown]
# # Stage-2：模型应用

# %%
import ModelUtils
import importlib
from collections import Counter
importlib.reload(ModelUtils)
# Out:
# c:\program files\python36\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# <module 'ModelUtils' from 'C:\\github_workspace\\ecoForest\\ModelUtils.py'>

# %%
from sklearn import metrics
def acc_metrix_mult(a, p):
#     print(p)
    return "acc", metrics.accuracy_score(a, p)

# %% [markdown]
# # DT, RF, GDBT, XGB 算法

# %%
ModelUtils.decision_tree(X_train, y_train, X_sub, y_sub, feval=acc_metrix_mult)
# Out:
# train ('acc', 0.99996928841251809)
# test ('acc', 0.81358638904244207)
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
ModelUtils.random_forest(X_train, y_train, X_sub, y_sub, n_estimators=200, feval=acc_metrix_mult,\
                         max_depth=3, min_samples_leaf=1, min_samples_split=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-aa1703e84060> in <module>()
# ----> 1 ModelUtils.random_forest(X_train, y_train, X_sub, y_sub, n_estimators=200, feval=acc_metrix_mult, max_depth=3, min_samples_leaf=1, min_samples_split=2)
#
# TypeError: random_forest() got an unexpected keyword argument 'max_depth'

# %%
ModelUtils.gdbt_model(X_train, y_train, X_sub, y_sub, n_estimators=1000, feval=acc_metrix_mult)
# Out:
# train ('acc', 0.89607198796105769)
# test ('acc', 0.8745777286407469)
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
ModelUtils.xgb_model(X_train, y_train, X_sub, y_sub, num_class=2, feval=acc_metrix_mult)
# Out:
# {'objective': 'multi:softmax', 'num_class': 2}
# [0]	train-acc:0.855318	valid-acc:0.85609
# Multiple eval metrics have been passed: 'valid-acc' will be used for early stopping.
#
# Will train until valid-acc hasn't improved in 500 rounds.
# [100]	train-acc:0.908357	valid-acc:0.871814
# [200]	train-acc:0.930561	valid-acc:0.869725
# [300]	train-acc:0.949203	valid-acc:0.865365
# [400]	train-acc:0.963668	valid-acc:0.865303
# [500]	train-acc:0.972697	valid-acc:0.864566
# Stopping. Best iteration:
# [31]	train-acc:0.885661	valid-acc:0.874332
#
# train ('acc', 0.97515432572709682)
# test ('acc', 0.86339905411215523)

# %% [markdown]
# # BaseLine

# %%
ModelUtils.baseline_1_flod(X_train, y_train, X_sub, y_sub, num_class=2, feval=acc_metrix_mult)
# Out:
# X_train.shape, y_train.shape:(32561, 14)(32561,)
# X_valid.shape, y_valid.shape:(16281, 14)(16281,)
#     cross_score: 0.85277
#     test score ('acc', 0.85467723112830907)
# train kflod pred: ('acc', 0.85467723112830907)
# train pred ('acc', 0.99996928841251809)
# test pred ('acc', 0.85467723112830907)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=1023, verbose=0,
#             warm_start=False)

# %%
ModelUtils.baseline_model(X_train, y_train, X_sub, y_sub, num_class=2, feval=acc_metrix_mult)
# Out:
# X_train.shape, y_train.shape:(26048, 14)(26048,)
# X_valid.shape, y_valid.shape:(6513, 14)(6513,)
#     cross_score: 0.85567
#     test score ('acc', 0.85320312020146183)
# X_train.shape, y_train.shape:(26049, 14)(26049,)
# X_valid.shape, y_valid.shape:(6512, 14)(6512,)
#     cross_score: 0.85258
#     test score ('acc', 0.85633560592101221)
# X_train.shape, y_train.shape:(26049, 14)(26049,)
# X_valid.shape, y_valid.shape:(6512, 14)(6512,)
#     cross_score: 0.85519
#     test score ('acc', 0.85418586081935999)
# X_train.shape, y_train.shape:(26049, 14)(26049,)
# X_valid.shape, y_valid.shape:(6512, 14)(6512,)
#     cross_score: 0.84874
#     test score ('acc', 0.85854677231128307)
# X_train.shape, y_train.shape:(26049, 14)(26049,)
# X_valid.shape, y_valid.shape:(6512, 14)(6512,)
#     cross_score: 0.84905
#     test score ('acc', 0.85541428659173269)
# train kflod pred: ('acc', 0.85755965725868366)
# train pred ('acc', 0.99996928841251809)
# test pred ('acc', 0.85633560592101221)
# lr train ('acc', 0.85734467614631005)
# lr test ('acc', 0.85848535102266443)
# lr coef_ -0.0413213944121
# [RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#              oob_score=False, random_state=1023, verbose=0,
#              warm_start=False),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#              oob_score=False, random_state=1023, verbose=0,
#              warm_start=False),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#              oob_score=False, random_state=1023, verbose=0,
#              warm_start=False),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#              oob_score=False, random_state=1023, verbose=0,
#              warm_start=False),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#              oob_score=False, random_state=1023, verbose=0,
#              warm_start=False)]

# %% [markdown]
# # Stage-3：EcoForest

# %%
import EnhancedForest_multiclass
import DecomposerForest
import LogUtils
import AlgorithmUtils
import importlib
importlib.reload(DecomposerForest)
importlib.reload(LogUtils)
importlib.reload(EnhancedForest_multiclass)
importlib.reload(AlgorithmUtils)
np.seterr(divide='ignore', invalid='ignore')
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# %history

# %%
decoForest = DecomposerForest.DecomposerForest(X_train, y_train, X_sub, y_sub, num_class=2, flag="adult", isLRStacker=True)
decoForest.set_parameter(criterion="gini", dropout=None, min_samples_leaf=10)
decoForest.fit(n_estimators=200, kfold=3, feval=acc_metrix_mult)
# Out:
# 2018-03-20 17:11:14 layer: 1
# all data ('acc', 0.87555664752311047)
# train loss ('acc', 0.87555664752311047)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86250422284327877)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86481174375038383)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 1 [p:0/np:0]
#
# 2018-03-20 17:11:20 layer: 2
# all data ('acc', 0.87574091704800217)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87574091704800217)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86179785633119377)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86456605859590929)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 2 [p:0/np:16281]
#
# 2018-03-20 17:11:29 layer: 3
# all data ('acc', 0.87564878228555632)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87564878228555632)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86167500998126589)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86481174375038383)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:11:37 layer: 4
# all data ('acc', 0.87531095482325483)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87531095482325483)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86173643315622983)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86462747988452793)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:11:46 layer: 5
# all data ('acc', 0.87638586038512334)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87638586038512334)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86253493443076068)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86389042442110431)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 5 [p:0/np:16281]
#
# 2018-03-20 17:11:55 layer: 6
# all data ('acc', 0.87531095482325483)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87531095482325483)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86179785633119377)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86382900313248567)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:12:04 layer: 7
# all data ('acc', 0.87571020546052025)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87571020546052025)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86222781855594111)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86425895215281612)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:12:13 layer: 8
# all data ('acc', 0.87531095482325483)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87531095482325483)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86158287521882004)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86419753086419748)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:12:23 layer: 9
# all data ('acc', 0.8758023402229661)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8758023402229661)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86201283744356749)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86376758184386704)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:12:33 layer: 10
# all data ('acc', 0.87534166641073674)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87534166641073674)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86198212585608547)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:12:44 layer: 11
# all data ('acc', 0.87537237799821876)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87537237799821876)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86207426061853132)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86389042442110431)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:12:55 layer: 12
# all data ('acc', 0.87604803292282174)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87604803292282174)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86173643315622983)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86395184570972294)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:13:06 layer: 13
# all data ('acc', 0.87518810847332695)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87518810847332695)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86130647093148249)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86438179473005339)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:13:19 layer: 14
# all data ('acc', 0.87592518657289398)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87592518657289398)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86167500998126589)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86382900313248567)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:13:31 layer: 15
# all data ('acc', 0.87515739688584504)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87515739688584504)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86195141426860356)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86419753086419748)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:13:45 layer: 16
# all data ('acc', 0.87623230244771355)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87623230244771355)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86222781855594111)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86462747988452793)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:13:58 layer: 17
# all data ('acc', 0.8758023402229661)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8758023402229661)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86207426061853132)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:14:12 layer: 18
# all data ('acc', 0.87558735911059238)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87558735911059238)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86158287521882004)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86401326699834158)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:14:27 layer: 19
# all data ('acc', 0.87607874451030376)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87607874451030376)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86238137649335089)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86425895215281612)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:14:42 layer: 20
# all data ('acc', 0.87601732133533983)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87601732133533983)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86139860569392834)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:14:57 layer: 21
# all data ('acc', 0.87558735911059238)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87558735911059238)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86201283744356749)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86358331797801113)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:15:13 layer: 22
# all data ('acc', 0.8758023402229661)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8758023402229661)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86146002886889228)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8647503224617652)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:15:30 layer: 23
# all data ('acc', 0.87515739688584504)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87515739688584504)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86213568379349526)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86401326699834158)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:15:47 layer: 24
# all data ('acc', 0.87558735911059238)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87558735911059238)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86133718251896441)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86438179473005339)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:16:04 layer: 25
# all data ('acc', 0.87555664752311047)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87555664752311047)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86142931728141026)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86401326699834158)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:16:22 layer: 26
# all data ('acc', 0.87610945609778568)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87610945609778568)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86253493443076068)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86481174375038383)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 26 [p:0/np:16281]
#
# 2018-03-20 17:16:40 layer: 27
# all data ('acc', 0.87567949387303834)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87567949387303834)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.8625656460182427)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86499600761623974)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 27 [p:0/np:16281]
#
# 2018-03-20 17:16:59 layer: 28
# all data ('acc', 0.87577162863548419)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87577162863548419)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86198212585608547)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 28 [p:0/np:16281]
#
# 2018-03-20 17:17:17 layer: 29
# all data ('acc', 0.87524953164829089)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87524953164829089)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86152145204385611)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86395184570972294)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:17:37 layer: 30
# all data ('acc', 0.8763244372101594)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8763244372101594)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86265778078068855)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86542595663657018)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# 30 [p:0/np:16281]
#
# 2018-03-20 17:17:56 layer: 31
# all data ('acc', 0.87552593593562855)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87552593593562855)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86173643315622983)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86456605859590929)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:18:16 layer: 32
# all data ('acc', 0.87518810847332695)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87518810847332695)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86115291299407271)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8637061605552484)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:18:37 layer: 33
# all data ('acc', 0.8761401676852677)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8761401676852677)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86216639538097728)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:18:57 layer: 34
# all data ('acc', 0.8756180706980744)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8756180706980744)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86167500998126589)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86382900313248567)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:19:19 layer: 35
# all data ('acc', 0.87543380117318259)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87543380117318259)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86188999109363962)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:19:40 layer: 36
# all data ('acc', 0.87488099259850738)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87488099259850738)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86099935505666292)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86407468828696021)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:20:02 layer: 37
# all data ('acc', 0.87546451276066461)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87546451276066461)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86204354903104941)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8637061605552484)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:20:24 layer: 38
# all data ('acc', 0.87531095482325483)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87531095482325483)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86222781855594111)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86511885019347701)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:20:46 layer: 39
# all data ('acc', 0.87555664752311047)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87555664752311047)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86207426061853132)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8637061605552484)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:21:09 layer: 40
# all data ('acc', 0.87552593593562855)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87552593593562855)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86103006664414483)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8647503224617652)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:21:32 layer: 41
# all data ('acc', 0.87515739688584504)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87515739688584504)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86247351125579685)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:21:54 layer: 42
# all data ('acc', 0.87601732133533983)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87601732133533983)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86222781855594111)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86413610957557885)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:22:18 layer: 43
# all data ('acc', 0.87592518657289398)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87592518657289398)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.8618592795061577)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86407468828696021)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:22:42 layer: 44
# all data ('acc', 0.87567949387303834)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87567949387303834)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86219710696845919)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86438179473005339)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:23:06 layer: 45
# all data ('acc', 0.87555664752311047)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87555664752311047)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86207426061853132)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86389042442110431)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:23:31 layer: 46
# all data ('acc', 0.87595589816037589)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87595589816037589)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86198212585608547)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86536453534795155)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:23:56 layer: 47
# all data ('acc', 0.87552593593562855)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87552593593562855)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86182856791867568)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86444321601867202)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:24:21 layer: 48
# all data ('acc', 0.87564878228555632)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87564878228555632)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86176714474371185)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86401326699834158)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:24:47 layer: 49
# all data ('acc', 0.87531095482325483)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87531095482325483)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86176714474371185)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:25:13 layer: 50
# all data ('acc', 0.87497312736095334)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87497312736095334)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86225853014342313)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86419753086419748)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:25:40 layer: 51
# all data ('acc', 0.87607874451030376)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87607874451030376)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86225853014342313)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86487316503900247)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:26:06 layer: 52
# all data ('acc', 0.8763244372101594)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8763244372101594)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86149074045637419)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86499600761623974)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:26:33 layer: 53
# all data ('acc', 0.87531095482325483)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87531095482325483)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86188999109363962)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86438179473005339)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:27:01 layer: 54
# all data ('acc', 0.87506526212339919)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87506526212339919)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86201283744356749)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86358331797801113)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:27:28 layer: 55
# all data ('acc', 0.87592518657289398)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87592518657289398)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86198212585608547)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86419753086419748)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:27:57 layer: 56
# all data ('acc', 0.87524953164829089)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87524953164829089)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86090722029421696)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86407468828696021)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:28:25 layer: 57
# all data ('acc', 0.87546451276066461)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87546451276066461)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86216639538097728)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:28:54 layer: 58
# all data ('acc', 0.87534166641073674)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87534166641073674)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86247351125579685)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86444321601867202)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:29:22 layer: 59
# all data ('acc', 0.87626301403519546)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87626301403519546)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86155216363133813)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:29:52 layer: 60
# all data ('acc', 0.87537237799821876)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87537237799821876)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86142931728141026)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86456605859590929)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:30:22 layer: 61
# all data ('acc', 0.8758023402229661)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8758023402229661)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86219710696845919)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:30:53 layer: 62
# all data ('acc', 0.87564878228555632)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87564878228555632)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86222781855594111)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86530311405933291)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:31:23 layer: 63
# all data ('acc', 0.87549522434814653)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87549522434814653)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86210497220601334)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86395184570972294)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:31:54 layer: 64
# all data ('acc', 0.87595589816037589)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87595589816037589)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86250422284327877)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86425895215281612)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:32:26 layer: 65
# all data ('acc', 0.87595589816037589)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87595589816037589)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86225853014342313)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86395184570972294)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:32:57 layer: 66
# all data ('acc', 0.87595589816037589)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87595589816037589)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.8625656460182427)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86419753086419748)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:33:29 layer: 67
# all data ('acc', 0.87583305181044813)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87583305181044813)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86161358680630207)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86413610957557885)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:34:01 layer: 68
# all data ('acc', 0.87574091704800217)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87574091704800217)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86231995331838707)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8637061605552484)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:34:34 layer: 69
# all data ('acc', 0.87607874451030376)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87607874451030376)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86235066490586898)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86487316503900247)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:35:07 layer: 70
# all data ('acc', 0.87534166641073674)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87534166641073674)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86173643315622983)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86487316503900247)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:35:41 layer: 71
# all data ('acc', 0.87583305181044813)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87583305181044813)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86133718251896441)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86462747988452793)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:36:14 layer: 72
# all data ('acc', 0.87577162863548419)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87577162863548419)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86213568379349526)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86444321601867202)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:36:48 layer: 73
# all data ('acc', 0.87558735911059238)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87558735911059238)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86188999109363962)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86462747988452793)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:37:22 layer: 74
# all data ('acc', 0.87549522434814653)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87549522434814653)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86146002886889228)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86401326699834158)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:37:58 layer: 75
# all data ('acc', 0.87574091704800217)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87574091704800217)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86213568379349526)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86395184570972294)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:38:33 layer: 76
# all data ('acc', 0.87629372562267749)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87629372562267749)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86219710696845919)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:39:08 layer: 77
# all data ('acc', 0.87549522434814653)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87549522434814653)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86121433616903653)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86389042442110431)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:39:44 layer: 78
# all data ('acc', 0.87577162863548419)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87577162863548419)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86195141426860356)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86358331797801113)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:40:20 layer: 79
# all data ('acc', 0.87506526212339919)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87506526212339919)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.8618592795061577)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86499600761623974)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:40:58 layer: 80
# all data ('acc', 0.87583305181044813)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87583305181044813)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86235066490586898)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86309194766906205)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:41:35 layer: 81
# all data ('acc', 0.87537237799821876)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87537237799821876)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86192070268112164)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86358331797801113)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:42:13 layer: 82
# all data ('acc', 0.87571020546052025)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87571020546052025)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86136789410644632)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86462747988452793)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:42:51 layer: 83
# all data ('acc', 0.87583305181044813)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87583305181044813)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.8618592795061577)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86425895215281612)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:43:29 layer: 84
# all data ('acc', 0.8752802432357728)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8752802432357728)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86219710696845919)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8647503224617652)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:44:07 layer: 85
# all data ('acc', 0.87586376339793004)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87586376339793004)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86161358680630207)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86419753086419748)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:44:47 layer: 86
# all data ('acc', 0.87604803292282174)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87604803292282174)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86219710696845919)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86413610957557885)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:45:26 layer: 87
# all data ('acc', 0.87574091704800217)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87574091704800217)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86195141426860356)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86444321601867202)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:46:05 layer: 88
# all data ('acc', 0.87571020546052025)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87571020546052025)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86198212585608547)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:46:46 layer: 89
# all data ('acc', 0.87620159086023153)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87620159086023153)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86146002886889228)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86468890117314656)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:47:27 layer: 90
# all data ('acc', 0.87534166641073674)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87534166641073674)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.8618592795061577)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86425895215281612)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:48:08 layer: 91
# all data ('acc', 0.87540308958570068)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87540308958570068)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86192070268112164)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86376758184386704)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:48:50 layer: 92
# all data ('acc', 0.8756180706980744)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8756180706980744)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86176714474371185)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86382900313248567)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:49:33 layer: 93
# all data ('acc', 0.87546451276066461)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87546451276066461)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86250422284327877)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86413610957557885)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:50:16 layer: 94
# all data ('acc', 0.87500383894843525)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87500383894843525)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86173643315622983)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86432037344143475)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:50:59 layer: 95
# all data ('acc', 0.87583305181044813)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87583305181044813)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86231995331838707)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86425895215281612)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:51:43 layer: 96
# all data ('acc', 0.87555664752311047)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87555664752311047)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86195141426860356)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.8647503224617652)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:52:28 layer: 97
# all data ('acc', 0.87592518657289398)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87592518657289398)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86207426061853132)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86450463730729066)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:53:13 layer: 98
# all data ('acc', 0.8758023402229661)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.8758023402229661)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86201283744356749)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86536453534795155)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:53:58 layer: 99
# all data ('acc', 0.87534166641073674)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87534166641073674)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86173643315622983)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86376758184386704)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:54:44 layer: 100
# all data ('acc', 0.87617087927274961)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87617087927274961)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86216639538097728)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86413610957557885)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# not pass
#
# 2018-03-20 17:55:31 layer: 101
# all data ('acc', 0.87583305181044813)
# [p:0/1:0|n:32561/1:7841]
# train loss ('acc', 0.87583305181044813)
# pass train loss (0, 0)
# pass train loss now (0, 1)
# vaild loss ('acc', 0.86228924173090504)
# pass vaild loss (0, 0)
# pass vaild loss now (0, 1)
# test loss ('acc', 0.86444321601867202)
# pass test loss (0, 0)
# pass test loss now (0, 1)
# STATUS_BREAK

# %%
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.86542595663657018,
#  [(0, 0.86481174375038383),
#   (1, 0.86456605859590929),
#   (2, 0.86389042442110431),
#   (3, 0.86481174375038383),
#   (4, 0.86499600761623974),
#   (5, 0.86432037344143475),
#   (6, 0.86542595663657018)])

# %%
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.86542595663657018,
#  [(0, 0.86481174375038383),
#   (1, 0.86456605859590929),
#   (2, 0.86389042442110431),
#   (3, 0.86481174375038383),
#   (4, 0.86499600761623974),
#   (5, 0.86432037344143475),
#   (6, 0.86542595663657018)])

# %%
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.86616301209999391,
#  [(0, 0.86481174375038383),
#   (1, 0.86456605859590929),
#   (2, 0.86548737792518882),
#   (3, 0.86462747988452793),
#   (4, 0.8649345863276211),
#   (5, 0.86450463730729066),
#   (6, 0.86389042442110431),
#   (7, 0.8647503224617652),
#   (8, 0.86487316503900247),
#   (9, 0.86499600761623974),
#   (10, 0.86481174375038383),
#   (11, 0.86536453534795155),
#   (12, 0.86468890117314656),
#   (13, 0.86499600761623974),
#   (14, 0.8649345863276211),
#   (15, 0.86444321601867202),
#   (16, 0.86450463730729066),
#   (17, 0.8649345863276211),
#   (18, 0.86499600761623974),
#   (19, 0.86518027148209564),
#   (20, 0.86511885019347701),
#   (21, 0.86511885019347701),
#   (22, 0.86518027148209564),
#   (23, 0.86481174375038383),
#   (24, 0.86597874823413801),
#   (25, 0.86616301209999391),
#   (26, 0.86518027148209564),
#   (27, 0.86456605859590929),
#   (28, 0.86425895215281612),
#   (29, 0.86487316503900247),
#   (30, 0.86518027148209564),
#   (31, 0.86518027148209564),
#   (32, 0.86487316503900247),
#   (33, 0.86548737792518882),
#   (34, 0.86597874823413801),
#   (35, 0.86462747988452793),
#   (36, 0.86597874823413801),
#   (37, 0.86511885019347701),
#   (38, 0.86536453534795155),
#   (39, 0.86456605859590929),
#   (40, 0.8649345863276211),
#   (41, 0.86561022050242609),
#   (42, 0.8647503224617652),
#   (43, 0.86450463730729066),
#   (44, 0.86419753086419748),
#   (45, 0.8647503224617652),
#   (46, 0.86499600761623974),
#   (47, 0.8647503224617652),
#   (48, 0.86462747988452793),
#   (49, 0.8649345863276211),
#   (50, 0.86456605859590929),
#   (51, 0.8649345863276211),
#   (52, 0.86505742890485837),
#   (53, 0.8649345863276211),
#   (54, 0.86481174375038383),
#   (55, 0.86462747988452793)])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
x = range(len(decoForest.train_loss_lt))

plt.subplot(221)
plt.plot(x[1:],decoForest.pass_train_loss_lt[1:], label="train-pass", color="blue")
plt.plot(x[1:],decoForest.pass_vaild_loss_lt[1:], label="vaild-pass", color="green")
plt.plot(x[1:],decoForest.pass_test_loss_lt[1:], label="test-pass", color="red")
plt.legend()
plt.subplot(222)
plt.plot(x[1:],decoForest.pass_train_loss_lt_now[1:], label="train-pass-now", color="blue")
plt.plot(x[1:],decoForest.pass_vaild_loss_lt_now[1:], label="vaild-pass-now", color="green")
plt.plot(x[1:],decoForest.pass_test_loss_lt_now[1:], label="test-pass-now", color="red")
plt.legend()
plt.subplot(223)
plt.plot(x,decoForest.train_loss_lt, label="train-loss", color="blue")
plt.plot(x,decoForest.vaild_loss_lt, label="vaild-loss", color="green")
plt.plot(x,decoForest.test_loss_lt, label="test-loss", color="red")
plt.legend()
plt.subplot(224)
plt.plot(x,decoForest.pass_data_rate_lt[:], label="data-pass-rate")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
x = range(len(decoForest.train_loss_lt))

plt.subplot(221)
plt.plot(x[1:],decoForest.pass_train_loss_lt[1:], label="train-pass", color="blue")
plt.plot(x[1:],decoForest.pass_vaild_loss_lt[1:], label="vaild-pass", color="green")
plt.plot(x[1:],decoForest.pass_test_loss_lt[1:], label="test-pass", color="red")
plt.legend()
plt.subplot(222)
plt.plot(x[1:],decoForest.pass_train_loss_lt_now[1:], label="train-pass-now", color="blue")
plt.plot(x[1:],decoForest.pass_vaild_loss_lt_now[1:], label="vaild-pass-now", color="green")
plt.plot(x[1:],decoForest.pass_test_loss_lt_now[1:], label="test-pass-now", color="red")
plt.legend()
plt.subplot(223)
plt.plot(x,decoForest.train_loss_lt, label="train-loss", color="blue")
plt.plot(x,decoForest.vaild_loss_lt, label="vaild-loss", color="green")
plt.plot(x,decoForest.test_loss_lt, label="test-loss", color="red")
plt.legend()
plt.subplot(224)
plt.plot(x,decoForest.pass_data_rate_lt[:], label="data-pass-rate")
plt.legend()

plt.show()

# %%
# n=200, criterion="gini", dropout=None, True-lr, kfold=3
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.85995946194951167,
#  [(0, 0.85946809164056259),
#   (1, 0.85977519808365577),
#   (2, 0.8586081935999017),
#   (3, 0.85971377679503713),
#   (4, 0.85934524906332532),
#   (5, 0.85922240648608805),
#   (6, 0.85995946194951167),
#   (7, 0.8596523555064185),
#   (8, 0.85879245746575761)])

# %%
# n=500, criterion="gini", dropout=None, True-lr, kfold=20
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.85639702720963085,
#  [(0, 0.85639702720963085),
#   (1, 0.85621276334377494),
#   (2, 0.85633560592101221),
#   (3, 0.85615134205515631),
#   (4, 0.85627418463239358)])

# %%
# n=500, criterion="gini", dropout=None, True-lr
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.85903814262023215,
#  [(0, 0.85780971684785945),
#   (1, 0.85817824457957126),
#   (2, 0.85891530004299488),
#   (3, 0.8584239297340458),
#   (4, 0.85793255942509672),
#   (5, 0.85793255942509672),
#   (6, 0.85799398071371535),
#   (7, 0.85848535102266443),
#   (8, 0.85811682329095262),
#   (9, 0.85830108715680853),
#   (10, 0.85823966586818989),
#   (11, 0.85756403169338491),
#   (12, 0.85768687427062218),
#   (13, 0.85823966586818989),
#   (14, 0.85854677231128307),
#   (15, 0.85903814262023215),
#   (16, 0.8586081935999017),
#   (17, 0.85805540200233399)])

# %%
# n=200, criterion="gini", dropout=None, True-lr
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.85909956390885078,
#  [(0, 0.85817824457957126),
#   (1, 0.85750261040476627),
#   (2, 0.85854677231128307),
#   (3, 0.85836250844542716),
#   (4, 0.85780971684785945),
#   (5, 0.85811682329095262),
#   (6, 0.85774829555924081),
#   (7, 0.8584239297340458),
#   (8, 0.85762545298200354),
#   (9, 0.85909956390885078),
#   (10, 0.85774829555924081),
#   (11, 0.85903814262023215),
#   (12, 0.85873103617713897),
#   (13, 0.85768687427062218),
#   (14, 0.85848535102266443)])

# %%
# n=200, criterion="gini", dropout=-1, True-lr
np.max(np.array(decoForest.test_loss_lt)),list(enumerate(decoForest.test_loss_lt) )
# Out:
# (0.85879245746575761,
#  [(0, 0.85817824457957126),
#   (1, 0.85750261040476627),
#   (2, 0.85836250844542716),
#   (3, 0.85793255942509672),
#   (4, 0.85756403169338491),
#   (5, 0.85879245746575761),
#   (6, 0.85688839751857993),
#   (7, 0.85787113813647808),
#   (8, 0.8584239297340458),
#   (9, 0.85836250844542716),
#   (10, 0.85799398071371535),
#   (11, 0.85811682329095262),
#   (12, 0.85787113813647808),
#   (13, 0.85756403169338491)])

# %% [markdown]
# # Todo list
# - 树结构设计（完成）
# - 通过gini对数据分割（完成）
# - 全局测试集
# - 输出结果集
# - 打印信息增加pass data的比例
# - 防止过拟合
# - 对pass data的进一步处理
# - 先进行数据均衡化是不是更快一些
